# %% [markdown]
# # Amazon data set analysis
#
# With the given data (amazon-meta.txt.gz) for 548552 products, perform exploratory analysis and make suggestions for further analysis on the following aspects.
#
# ## 1. Trustworthiness of ratings
#
# Ratings are susceptible to manipulation, bias etc. What can you say (quantitatively speaking) about the ratings in this dataset?
#
# In order to answer this question, let's focus on the following data:
#   - average rating
#   - number of downloads
#   - votes for a rating
#   - rating helpfulness
#
# We are interested in a product that has more than 10 ratings, at least 5 rating votes and 5 rating helpfulness votes.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import re
import numpy as np
from scipy.stats.stats import pearsonr

# %%
import gzip

row_limit = -1
row_count = 0

# create the empty dataframe
dataDF = pd.DataFrame(columns = ['id', 'asin', 'group', 'salesrank', 'categories'])

# the collection we use to fill the dataframe
collection = []

# the collection we use to load the rating for each of the product
ratings_tab = []

# the regular expression for review header
review_reg = 'reviews: total:.*downloaded:.*avg rating:.*'

# regular expression for review item lines
rev_item_reg = '\d{4}-\d+-\d+  cutomer: .*  rating: \d  votes:   \d+  helpful:   \d+'

with gzip.open('amazon-meta.txt.gz') as in_file:
    for line in in_file: 
        line_s = line.strip().decode('utf-8').lower()
        if len(line_s) == 0  or line_s[0] == '#':
            continue
        row_count += 1
        rating_item = {}
        
        # if a product id is encountered we store the collected information and clean the temporary storage vars
        if re.match('id:\s+\d+', line_s) is not None:
            if len(ratings_tab) > 9:
                ratings_array = [float(x['rating']) for x in ratings_tab]
                votes_array = [float(x['votes']) for x in ratings_tab]
                h_array = [float(x['helpful']) for x in ratings_tab]
                rec['rating_sd'] = np.std(ratings_array)
                rec['votes_avg'] = np.mean(votes_array)
                rec['votes_sd'] = np.std(votes_array)
                rec['help_avg'] = np.mean(h_array)
                rec['help_sd'] = np.std(h_array)
                rec['hv_corr'] = pearsonr(h_array, 
                                             y=votes_array)[0]
                rec['help_fratio'] = sum([ (1 if x > 0 else 0) for x in h_array])/len(ratings_tab)
                rec['votes_fratio'] = sum([ (1 if x > 0 else 0) for x in votes_array])/len(ratings_tab)
                collection.append(rec)
            rec = {}
            ratings_tab = []
            rec['id'] = line_s.split(':')[1].strip()
            
        
        if 'asin:' in line_s:
            rec['asin'] = line_s.split(':')[1].strip()
        if 'salesrank:' in line_s:
            rec['salesrank'] = line_s.split(':')[1].strip()
        if 'group:' in line_s:
            rec['group'] = line_s.split(':')[1].strip()
        if 'categories:' in line_s:
            rec['categories'] = line_s.split(':')[1].strip()
        if re.match(review_reg, line_s) is not None:
            rec['reviews_average'] = line_s.split(':')[4].strip()
            rec['reviews_total'] = re.findall('\d+', line_s.split(':')[2])[0]
            rec['reviews_downloads'] = re.findall('\d+', line_s.split(':')[2])[0]
        if re.match(rev_item_reg, line_s):
            rating_item['rating'] = re.findall('\d+', line_s.split(':')[2])[0]
            rating_item['votes'] = re.findall('\d+', line_s.split(':')[3])[0]
            rating_item['helpful'] = re.findall('\d+', line_s.split(':')[4])[0]
            ratings_tab.append(rating_item)
            
        if row_count == row_limit:
            break
# fill the dataframe with results
dataDF = dataDF.append(collection)

# delete the collection variable
del collection
# Out:
# /Users/klitonandrea/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
dataDF.head()
# Out:
#          asin categories  group  help_avg  help_fratio   help_sd   hv_corr  \
# 0  0738700797          2   book  5.100000     1.000000  1.920937  0.896439
# 1  1590770218          9   book  3.900000     1.000000  1.757840  0.631842
# 2  0195110382          3   book  2.400000     0.900000  1.280625  0.925996
# 3  b000007r0t          1  music  0.928571     0.357143  1.667517  0.553947
# 4  0790747324         26    dvd  2.200000     0.848000  1.943193  0.839643
#
#    id  rating_sd reviews_average reviews_downloads reviews_total salesrank  \
# 0   2   0.458258             4.5                12            12    168596
# 1  12   1.577973             4.5                12            12     24741
# 2  16   0.670820             4.5                10            10    631564
# 3  18   0.515079               5                15            15    109301
# 4  21   0.724254             4.5               140           140       795
#
#    votes_avg  votes_fratio  votes_sd
# 0      5.500      1.000000  2.061553
# 1      5.600      1.000000  1.854724
# 2      3.000      1.000000  1.264911
# 3      2.500      0.571429  2.745126
# 4      3.072      0.904000  2.280968

# %% [markdown]
# We convert to numeric those columns that are numeric but of text type:

# %%
dataDF.reviews_average = pd.to_numeric(dataDF.reviews_average)
dataDF.reviews_downloads =  pd.to_numeric(dataDF.reviews_downloads) 
dataDF.reviews_total = pd.to_numeric(dataDF.reviews_total)

# %% [markdown]
# Now, we can have a look at the features that were extracted:

# %%
dataDF.describe()
# Out:
#            help_avg   help_fratio       help_sd       hv_corr     rating_sd  \
# count  94091.000000  94091.000000  94091.000000  94039.000000  94091.000000
# mean       2.070926      0.711468      1.817849      0.827339      0.881573
# std        1.006368      0.195810      0.505384      0.138606      0.398520
# min        0.000000      0.000000      0.000000     -0.575055      0.000000
# 25%        1.312500      0.583333      1.481741      0.764384      0.594816
# 50%        1.942857      0.736842      1.833030      0.854374      0.881396
# 75%        2.705882      0.866667      2.165641      0.927713      1.183216
# max        7.454545      1.000000      3.924283      1.000000      2.000000
#
#        reviews_average  reviews_downloads  reviews_total     votes_avg  \
# count     94091.000000       94091.000000   94091.000000  94091.000000
# mean          4.228656          67.647756      67.647756      2.917819
# std           0.573216         163.129870     163.129870      1.246073
# min           1.000000          10.000000      10.000000      0.000000
# 25%           4.000000          16.000000      16.000000      2.000000
# 50%           4.500000          27.000000      27.000000      2.815217
# 75%           4.500000          57.000000      57.000000      3.750000
# max           5.000000        5545.000000    5545.000000      8.000000
#
#        votes_fratio      votes_sd
# count  94091.000000  94091.000000
# mean       0.805622      2.158023
# std        0.172554      0.491143
# min        0.000000      0.000000
# 25%        0.708333      1.880742
# 50%        0.846154      2.215789
# 75%        0.936508      2.490799
# max        1.000000      4.049984

# %% [markdown]
# From the table above we do see that 'reviews_total' is duplicated by 'reviews_downloads' or at least they are strongly correlated.
#
# Another feature of interest is 'hv_corr'. It captures the correlation between the votes that a review has received and the helpfulness of the review. A negative correlation denotes the reviews that are highly voted but not helpful or vice versa. We will consider trustworthy, those reviews that have a strong positive correlation coefficient given by 'hv_corr'.

# %% [markdown]
# ## 2. Category bloat
#
# Consider the product group named 'Books'. Each product in this group is associated with categories. Naturally, with categorization, there are tradeoffs between how broad or specific the categories must be.
#
# For this dataset, quantify the following:
#
#     a. Is there redundancy in the categorization? How can it be identified/removed?
#     b. Is it possible to reduce the number of categories drastically (say to 10% of existing categories) by sacrificing relatively few category entries (say close to 10%)?
#
# To answer the questions above we need to count all the categories for 'Books' group that are listed for each item.

# %%
row_limit = -1
row_count = 0

# dictionary that holds all category counts
categories_count = {}

# dictionary that holds all leaf category counts
categories_entr_count = {}

# the collection we use to load the rating for each of the product
categories_lines = []

# the regular expression for category item
cat_item_reg = "(\|.*\[.*\])+"

with gzip.open('amazon-meta.txt.gz') as in_file:
    for line in in_file: 
        line_s = line.strip().decode('utf-8').lower()
        if len(line_s) == 0  or line_s[0] == '#':
            continue
        row_count += 1
        # if a product id is encountered we store the collected information and clean the temporary storage vars
        if re.match('id:\s+\d+', line_s) is not None:
            
            if 'group' not in rec:
                continue
            if rec['group'] != 'book':
                rec = {}
                categories_lines = []
                continue
            for cline in categories_lines:
                cats = cline.split('|')
                
                # considering only the last category (leaf) in category entry
                category = cats[len(cats) - 1]
                if category in categories_entr_count:
                    categories_entr_count[category] += 1
                else:
                    categories_entr_count[category] = 1
                
                # considering all categories in category entry
                for category in cats:
                    if category in categories_count:
                        categories_count[category] += 1
                    else:
                        categories_count[category] = 1
            rec={}                
            categories_lines = []
            
        if 'group:' in line_s:
            rec['group'] = line_s.split(':')[1].strip()
        if re.match(cat_item_reg, line_s) is not None:
            categories_lines.append(line_s)
        if row_count == row_limit:
            break

# %%
import operator
sorted_categories_by_key = sorted(categories_count.items(), key=operator.itemgetter(0))
sorted_categories_by_val = sorted(categories_count.items(), key = operator.itemgetter(1), reverse=True)

# %%
sum_of_sorted = sum([x[1] for x in sorted_categories_by_val[1:]])

# %%
sorted_categories_by_key[1:]
# Out:
# [('( a )[12833]', 78),
#  ('( a )[14653]', 398),
#  ('( a )[170541]', 541),
#  ('( a )[287121]', 53),
#  ('( a )[287148]', 7),
#  ('( a )[297872]', 203),
#  ('( a )[5440]', 72),
#  ('( a )[585708]', 10),
#  ('( a )[69301]', 31),
#  ('( a )[70022]', 629),
#  ('( a )[70740]', 8),
#  ('( a )[70836]', 33),
#  ('( a )[912594]', 113),
#  ('( a )[916930]', 95),
#  ('( a-c )[1105]', 281),
#  ('( b )[12855]', 290),
#  ('( b )[14711]', 762),
#  ('( b )[170542]', 1539),
#  ('( b )[287122]', 45),
#  ('( b )[287149]', 11),
#  ('( b )[297873]', 390),
#  ('( b )[411316]', 4),
#  ('( b )[5603]', 138),
#  ('( b )[585600]', 43),
#  ('( b )[585710]', 9),
#  ('( b )[69302]', 344),
#  ('( b )[70023]', 763),
#  ('( b )[70741]', 29),
#  ('( b )[70837]', 28),
#  ('( b )[7346]', 13),
#  ('( b )[912596]', 109),
#  ('( b )[916932]', 135),
#  ('( c )[12660]', 4),
#  ('( c )[12894]', 277),
#  ('( c )[14875]', 458),
#  ('( c )[170543]', 790),
#  ('( c )[287123]', 169),
#  ('( c )[287150]', 67),
#  ('( c )[297874]', 649),
#  ('( c )[416120]', 1),
#  ('( c )[585602]', 6),
#  ('( c )[585712]', 4),
#  ('( c )[5956]', 87),
#  ('( c )[69303]', 1013),
#  ('( c )[70024]', 538),
#  ('( c )[70838]', 13),
#  ('( c )[912598]', 161),
#  ('( c )[916934]', 159),
#  ('( d )[12940]', 260),
#  ('( d )[14990]', 436),
#  ('( d )[15746]', 6),
#  ('( d )[170544]', 473),
#  ('( d )[287124]', 61),
#  ('( d )[287151]', 18),
#  ('( d )[297875]', 289),
#  ('( d )[585604]', 31),
#  ('( d )[585660]', 10),
#  ('( d )[6268]', 79),
#  ('( d )[69304]', 292),
#  ('( d )[70025]', 640),
#  ('( d )[70743]', 1),
#  ('( d )[70839]', 2),
#  ('( d )[912600]', 87),
#  ('( d )[916936]', 86),
#  ('( d-f )[1185]', 156),
#  ('( e )[12968]', 77),
#  ('( e )[15085]', 118),
#  ('( e )[170545]', 96),
#  ('( e )[17964]', 1),
#  ('( e )[287125]', 17),
#  ('( e )[287152]', 10),
#  ('( e )[297876]', 123),
#  ('( e )[585606]', 1),
#  ('( e )[6457]', 38),
#  ('( e )[69305]', 145),
#  ('( e )[70026]', 141),
#  ('( e )[916938]', 91),
#  ('( f )[12982]', 77),
#  ('( f )[15125]', 177),
#  ('( f )[170546]', 237),
#  ('( f )[18353]', 1),
#  ('( f )[194000]', 24),
#  ('( f )[287126]', 23),
#  ('( f )[297877]', 68),
#  ('( f )[579522]', 1),
#  ('( f )[585718]', 3),
#  ('( f )[69306]', 200),
#  ('( f )[70027]', 245),
#  ('( f )[70745]', 4),
#  ('( f )[912604]', 36),
#  ('( f )[916940]', 120),
#  ('( g )[13007]', 211),
#  ('( g )[15211]', 360),
#  ('( g )[170547]', 303),
#  ('( g )[19383]', 6),
#  ('( g )[287127]', 72),
#  ('( g )[287154]', 37),
#  ('( g )[297878]', 177),
#  ('( g )[585610]', 12),
#  ('( g )[585666]', 1),
#  ('( g )[585720]', 1),
#  ('( g )[6531]', 89),
#  ('( g )[69307]', 449),
#  ('( g )[70028]', 394),
#  ('( g )[70746]', 8),
#  ('( g )[70842]', 9),
#  ('( g )[912606]', 32),
#  ('( g )[916942]', 108),
#  ('( g-i )[1227]', 179),
#  ('( h )[13036]', 287),
#  ('( h )[15304]', 456),
#  ('( h )[170548]', 612),
#  ('( h )[20886]', 4),
#  ('( h )[287128]', 38),
#  ('( h )[287155]', 8),
#  ('( h )[297879]', 139),
#  ('( h )[426368]', 1),
#  ('( h )[47995]', 1),
#  ('( h )[585612]', 14),
#  ('( h )[585722]', 2),
#  ('( h )[6918]', 136),
#  ('( h )[69308]', 279),
#  ('( h )[70029]', 549),
#  ('( h )[70747]', 5),
#  ('( h )[912608]', 102),
#  ('( h )[916944]', 53),
#  ('( i )[13067]', 7),
#  ('( i )[15386]', 27),
#  ('( i )[170549]', 94),
#  ('( i )[287129]', 4),
#  ('( i )[297880]', 10),
#  ('( i )[69309]', 10),
#  ('( i )[70030]', 106),
#  ('( i )[70748]', 1),
#  ('( i )[7260]', 2),
#  ('( i )[912610]', 14),
#  ('( i )[916946]', 6),
#  ('( j )[13072]', 123),
#  ('( j )[15395]', 117),
#  ('( j )[170550]', 154),
#  ('( j )[22548]', 1),
#  ('( j )[287130]', 99),
#  ('( j )[287157]', 49),
#  ('( j )[297881]', 332),
#  ('( j )[585616]', 9),
#  ('( j )[69310]', 84),
#  ('( j )[70031]', 217),
#  ('( j )[70749]', 12),
#  ('( j )[7280]', 97),
#  ('( j )[912612]', 12),
#  ('( j )[916948]', 132),
#  ('( j-l )[1272]', 136),
#  ('( k )[13084]', 227),
#  ('( k )[15431]', 200),
#  ('( k )[170551]', 550),
#  ('( k )[287131]', 76),
#  ('( k )[287158]', 17),
#  ('( k )[297882]', 290),
#  ('( k )[585618]', 14),
#  ('( k )[69311]', 151),
#  ('( k )[70032]', 319),
#  ('( k )[70846]', 12),
#  ('( k )[7386]', 415),
#  ('( k )[912614]', 25),
#  ('( k )[916950]', 119),
#  ('( l )[13119]', 256),
#  ('( l )[15504]', 410),
#  ('( l )[170552]', 495),
#  ('( l )[24132]', 1),
#  ('( l )[287132]', 106),
#  ('( l )[287159]', 48),
#  ('( l )[297883]', 655),
#  ('( l )[432148]', 2),
#  ('( l )[585620]', 3),
#  ('( l )[585676]', 10),
#  ('( l )[585730]', 23),
#  ('( l )[69312]', 275),
#  ('( l )[70033]', 273),
#  ('( l )[70751]', 4),
#  ('( l )[7615]', 135),
#  ('( l )[912616]', 74),
#  ('( l )[916952]', 222),
#  ('( m )[13153]', 370),
#  ('( m )[15568]', 514),
#  ('( m )[170553]', 884),
#  ('( m )[25497]', 8),
#  ('( m )[287133]', 49),
#  ('( m )[287160]', 6),
#  ('( m )[297884]', 623),
#  ('( m )[434574]', 3),
#  ('( m )[459370]', 1),
#  ('( m )[585622]', 24),
#  ('( m )[585678]', 15),
#  ('( m )[585732]', 5),
#  ('( m )[69313]', 364),
#  ('( m )[70034]', 820),
#  ('( m )[70848]', 1),
#  ('( m )[7836]', 109),
#  ('( m )[912618]', 71),
#  ('( m )[916954]', 124),
#  ('( m-o )[1316]', 230),
#  ('( n )[13191]', 59),
#  ('( n )[15710]', 110),
#  ('( n )[170554]', 122),
#  ('( n )[194001]', 17),
#  ('( n )[287134]', 9),
#  ('( n )[297885]', 155),
#  ('( n )[69314]', 43),
#  ('( n )[70035]', 138),
#  ('( n )[912620]', 103),
#  ('( n )[916956]', 36),
#  ('( o )[13196]', 37),
#  ('( o )[15735]', 53),
#  ('( o )[170555]', 100),
#  ('( o )[194002]', 9),
#  ('( o )[27900]', 1),
#  ('( o )[287135]', 20),
#  ('( o )[297886]', 131),
#  ('( o )[585626]', 5),
#  ('( o )[69315]', 27),
#  ('( o )[70036]', 335),
#  ('( o )[70850]', 3),
#  ('( o )[916958]', 26),
#  ('( p )[13201]', 136),
#  ('( p )[15755]', 329),
#  ('( p )[170556]', 675),
#  ('( p )[28166]', 6),
#  ('( p )[287136]', 63),
#  ('( p )[287163]', 23),
#  ('( p )[297887]', 259),
#  ('( p )[585628]', 12),
#  ('( p )[585684]', 2),
#  ('( p )[69316]', 573),
#  ('( p )[70037]', 262),
#  ('( p )[70851]', 38),
#  ('( p )[8313]', 110),
#  ('( p )[912624]', 249),
#  ('( p )[916960]', 59),
#  ('( p-r )[1359]', 220),
#  ('( q )[13222]', 16),
#  ('( q )[287137]', 5),
#  ('( q )[297888]', 10),
#  ('( q )[585686]', 2),
#  ('( q )[69317]', 2),
#  ('( q )[70038]', 26),
#  ('( r )[13226]', 288),
#  ('( r )[15820]', 186),
#  ('( r )[170558]', 467),
#  ('( r )[287138]', 70),
#  ('( r )[287165]', 26),
#  ('( r )[29612]', 3),
#  ('( r )[297889]', 123),
#  ('( r )[585632]', 6),
#  ('( r )[585742]', 14),
#  ('( r )[69318]', 168),
#  ('( r )[70039]', 386),
#  ('( r )[8574]', 172),
#  ('( r )[912628]', 64),
#  ('( r )[916964]', 146),
#  ('( s )[13255]', 315),
#  ('( s )[157485]', 1),
#  ('( s )[15869]', 498),
#  ('( s )[170559]', 1453),
#  ('( s )[287139]', 84),
#  ('( s )[287166]', 26),
#  ('( s )[297890]', 392),
#  ('( s )[31014]', 8),
#  ('( s )[444858]', 1),
#  ('( s )[585634]', 38),
#  ('( s )[585690]', 2),
#  ('( s )[585744]', 6),
#  ('( s )[69319]', 293),
#  ('( s )[70040]', 1592),
#  ('( s )[70758]', 399),
#  ('( s )[70854]', 89),
#  ('( s )[8806]', 408),
#  ('( s )[912630]', 117),
#  ('( s )[916966]', 54),
#  ('( s-u )[1405]', 128),
#  ('( t )[13303]', 23),
#  ('( t )[16011]', 636),
#  ('( t )[170560]', 178),
#  ('( t )[194003]', 27),
#  ('( t )[287140]', 32),
#  ('( t )[287167]', 33),
#  ('( t )[297891]', 307),
#  ('( t )[33698]', 3),
#  ('( t )[585746]', 17),
#  ('( t )[69320]', 86),
#  ('( t )[70041]', 586),
#  ('( t )[70759]', 2),
#  ('( t )[70855]', 10),
#  ('( t )[912632]', 51),
#  ('( t )[916968]', 30),
#  ('( u )[170561]', 9),
#  ('( u )[194004]', 2),
#  ('( u )[287141]', 4),
#  ('( u )[297892]', 13),
#  ('( u )[70042]', 39),
#  ('( v )[13318]', 7),
#  ('( v )[16049]', 108),
#  ('( v )[170562]', 174),
#  ('( v )[194005]', 15),
#  ('( v )[287142]', 15),
#  ('( v )[287169]', 16),
#  ('( v )[297893]', 15),
#  ('( v )[34713]', 4),
#  ('( v )[585750]', 4),
#  ('( v )[69322]', 48),
#  ('( v )[70043]', 123),
#  ('( v )[912636]', 48),
#  ('( v-z )[1440]', 138),
#  ('( w )[13323]', 39),
#  ('( w )[16082]', 422),
#  ('( w )[170563]', 490),
#  ('( w )[287143]', 44),
#  ('( w )[287170]', 6),
#  ('( w )[297894]', 403),
#  ('( w )[35334]', 2),
#  ('( w )[451116]', 2),
#  ('( w )[585642]', 15),
#  ('( w )[585698]', 1),
#  ('( w )[585752]', 11),
#  ('( w )[69323]', 170),
#  ('( w )[70044]', 690),
#  ('( w )[70762]', 23),
#  ('( w )[70858]', 15),
#  ('( w )[912638]', 97),
#  ('( w )[916974]', 119),
#  ('( w )[9425]', 88),
#  ('( y )[13348]', 6),
#  ('( y )[16174]', 58),
#  ('( y )[170565]', 179),
#  ('( y )[194006]', 29),
#  ('( y )[287145]', 7),
#  ('( y )[297895]', 114),
#  ('( y )[70046]', 25),
#  ('( y )[916978]', 12),
#  ('( z )[16180]', 28),
#  ('( z )[170566]', 125),
#  ('( z )[297896]', 79),
#  ('( z )[453752]', 1),
#  ('( z )[585758]', 10),
#  ('( z )[70047]', 16),
#  ('.net[764452]', 96),
#  ('10-12 years[300305]', 2),
#  ('17th century[465332]', 34),
#  ('1800s[2948]', 187),
#  ('1800s[2957]', 434),
#  ('18th century[10017]', 13),
#  ('18th century[10098]', 9),
#  ('18th century[465184]', 91),
#  ('18th century[5036]', 67),
#  ('18th century[9930]', 4),
#  ('1900s[2949]', 116),
#  ('1900s[2958]', 273),
#  ('1945 - present[4862]', 191),
#  ("1950's & 1960's[13752151]", 52),
#  ('1950s[4863]', 39),
#  ('1960s[4864]', 149),
#  ("1970's[13752161]", 26),
#  ("1980's[13752171]", 25),
#  ("1990's through 2004[13752181]", 154),
#  ('1996[68108]', 6),
#  ('1997[68109]', 11),
#  ('1998[68110]', 7),
#  ('1999[68111]', 10),
#  ('19th century[10019]', 60),
#  ('19th century[10100]', 29),
#  ('19th century[1043878]', 23),
#  ('19th century[170082]', 538),
#  ('19th century[465186]', 136),
#  ('19th century[4854]', 1127),
#  ('19th century[5037]', 128),
#  ('19th century[9932]', 42),
#  ('19th century[9970]', 16),
#  ('20th century[10021]', 137),
#  ('20th century[10102]', 21),
#  ('20th century[1043880]', 29),
#  ('20th century[465188]', 161),
#  ('20th century[4861]', 1537),
#  ('20th century[5038]', 482),
#  ('20th century[9934]', 76),
#  ('20th century[9972]', 1871),
#  ('21st century[1196142]', 94),
#  ('21st century[1199698]', 4),
#  ('3-6 years[300303]', 1),
#  ('3d graphics[4135]', 15),
#  ('3d studio max[4136]', 50),
#  ('3d studio max[768308]', 50),
#  ('4 a 8 años[301739]', 631),
#  ('7-11 years[403590]', 1),
#  ('7-9 years[300304]', 2),
#  ('77[3978]', 7),
#  ('8[588478]', 7),
#  ('8i[588476]', 11),
#  ('9 a 12 años[301740]', 195),
#  ('90[3979]', 15),
#  ('[139452]', 81),
#  ('[171280]', 95),
#  ('[172282]', 11204),
#  ('[229220]', 1096),
#  ('[229534]', 6924),
#  ('[265523]', 123925),
#  ('[468642]', 1465),
#  ('[540744]', 8517),
#  ('[700060]', 16),
#  ("a bug's life[184958]", 10),
#  ('a look inside[290717]', 2),
#  ('a to z mysteries[281810]', 19),
#  ('a+[3450]', 54),
#  ('a+[3481]', 54),
#  ('aaa[17057]', 4),
#  ('aaa[640120]', 4),
#  ('aalto, alvar[1009]', 6),
#  ('ab workouts[282945]', 20),
#  ('abbey, edward[70048]', 12),
#  ('abbey, lynn[14659]', 11),
#  ('abbott, edwin a.[14661]', 4),
#  ('abdominal[465676]', 86),
#  ('abe, shana[12834]', 6),
#  ('abstract expressionism[1068]', 24),
#  ('abstract[13889]', 16),
#  ('abstract[227384]', 15),
#  ('abuse & self defense[4683]', 338),
#  ('abuse[282908]', 135),
#  ('abuse[3124]', 126),
#  ('academic & commercial[12017]', 271),
#  ('acapulco[640284]', 5),
#  ('acapulco[67662]', 5),
#  ('access 2000[173218]', 119),
#  ('access 2000[768376]', 119),
#  ('access guides[17059]', 4),
#  ('access guides[640122]', 4),
#  ('access, filemaker & more[768438]', 264),
#  ('access[3482]', 26),
#  ('access[4089]', 208),
#  ('access[768442]', 208),
#  ('accessories[10505]', 20),
#  ('accessories[265040]', 971),
#  ('accidental heroes[291145]', 1),
#  ('accounting & finance[173509]', 2642),
#  ('accounting[2614]', 13),
#  ('accounting[2625]', 2153),
#  ('accounting[266117]', 1149),
#  ('accounting[491564]', 343),
#  ('accounting[549708]', 10),
#  ('accounting[69760]', 215),
#  ('accounting[727704]', 215),
#  ('accounting[767884]', 2359),
#  ('accounting[768120]', 13),
#  ('accounting[768210]', 10),
#  ('achebe, chinua[70049]', 15),
#  ('achilli, justin[5444]', 3),
#  ('acker, kathy[70050]', 13),
#  ('ackerman, forrest[5446]', 1),
#  ('ackroyd, peter[70051]', 5),
#  ('acoustics & sound[14547]', 240),
#  ('acoustics & sound[227400]', 212),
#  ('acoustics[226716]', 27),
#  ('acrobat[4138]', 22),
#  ('acrobat[768262]', 22),
#  ('act (american college tests)[11670]', 32),
#  ('act![172404]', 13),
#  ('act![727682]', 13),
#  ('act![768460]', 13),
#  ('acting & auditioning[2155]', 395),
#  ('action & adventure[2967]', 4061),
#  ('action & adventure[720360]', 1212),
#  ('active directory[285853]', 22),
#  ('active directory[768198]', 22),
#  ('active server pages[3601]', 182),
#  ('activex[3602]', 12),
#  ('activism[10705]', 11),
#  ('activities & toys[3372]', 604),
#  ('activity books[3373]', 2018),
#  ('actors & actresses[140]', 1),
#  ('actors & actresses[2328]', 429),
#  ('actors & actresses[404278]', 15),
#  ('actors[17420]', 10),
#  ('acupuncture & acupressure[4698]', 218),
#  ('acupuncture[14040]', 98),
#  ('acupuncture[227585]', 94),
#  ('ada compliant[266165]', 11),
#  ('ada[3953]', 13),
#  ('adams, adrienne[170567]', 1),
#  ('adams, ansel[1107]', 34),
#  ('adams, ansel[733582]', 34),
#  ('adams, charles j.[5450]', 1),
#  ('adams, douglas[14668]', 34),
#  ('adams, jay[297897]', 10),
#  ('adams, john[916986]', 23),
#  ('adams, richard[14670]', 7),
#  ('adams, richard[70052]', 2),
#  ('adaptations[4485]', 52),
#  ('address books[502874]', 27),
#  ('address books[642286]', 20),
#  ('addy[281854]', 12),
#  ('adirondacks[640756]', 14),
#  ('adirondacks[67513]', 14),
#  ('adler, david a.[170569]', 100),
#  ('administration & management[227652]', 120),
#  ('administration & medicine economics[227560]', 1593),
#  ('administration & policy[13998]', 1846),
#  ('administration[3780]', 33),
#  ('administration[491352]', 51),
#  ('administration[69830]', 738),
#  ('administrative law[173492]', 551),
#  ('administrative law[227433]', 500),
#  ('adobe framemaker[4095]', 10),
#  ('adobe indesign[295224]', 10),
#  ('adobe pagemaker[4096]', 20),
#  ('adobe photoshop[3527]', 215),
#  ('adobe[4137]', 373),
#  ('adoff, arnold[170570]', 7),
#  ('adolescent psychology[11121]', 300),
#  ('adolescent[227703]', 53),
#  ('adolescentes[301741]', 81),
#  ('adoption books[692268]', 161),
#  ('adoption[11350]', 180),
#  ('adoption[13984151]', 8),
#  ('adoption[3046]', 115),
#  ('adrian, jack[5456]', 1),
#  ('adult & continuing education[69822]', 172),
#  ('adult children of alcoholics[4718]', 32),
#  ('adult coloring books[5162]', 59),
#  ('adult fiction[10143]', 515),
#  ('advanced mechanics[226500]', 965),
#  ('advanced placement[11672]', 123),
#  ('advanced[3254]', 9),
#  ('advanced[502000]', 5),
#  ('advanced[502106]', 2),
#  ('advanced[502146]', 1),
#  ('advanced[502176]', 5),
#  ('advanced[502196]', 4),
#  ('advanced[502236]', 5),
#  ('advanced[502256]', 2),
#  ('advanced[502266]', 5),
#  ('advanced[502276]', 4),
#  ('advanced[502286]', 4),
#  ('advanced[502296]', 3),
#  ('advanced[502306]', 5),
#  ('advanced[502316]', 6),
#  ('advanced[502416]', 1),
#  ('advanced[506928]', 6),
#  ('advanced[506962]', 9),
#  ('advanced[506974]', 2),
#  ('advanced[727684]', 2),
#  ('advanced[727742]', 5),
#  ('advanced[727754]', 6),
#  ('advanced[727782]', 4),
#  ('advanced[727816]', 5),
#  ('advanced[727834]', 6),
#  ('advanced[768236]', 5),
#  ('advanced[768268]', 5),
#  ('advanced[768280]', 4),
#  ('advanced[768292]', 1),
#  ('advanced[768312]', 2),
#  ('advanced[768342]', 1),
#  ('advanced[768414]', 6),
#  ('advanced[768432]', 6),
#  ('advanced[768444]', 5),
#  ('advanced[768462]', 2),
#  ('advanced[768474]', 5),
#  ('advanced[768486]', 4),
#  ('advanced[768500]', 4),
#  ('advanced[768512]', 3),
#  ('advanced[768528]', 9),
#  ('advanced[768540]', 2),
#  ('advanced[768554]', 5),
#  ('advent[642312]', 13),
#  ('advent[67242]', 15),
#  ('adventure & thrillers[17416]', 705),
#  ('adventure guides[17061]', 21),
#  ('adventure guides[640124]', 21),
#  ('adventure[1087716]', 1),
#  ('adventure[16273]', 956),
#  ('adventure[17207]', 1124),
#  ('adventure[586094]', 171),
#  ('adventure[640362]', 2379),
#  ('adventurers & explorers[171115]', 117),
#  ('adventures in odyssey[269550]', 55),
#  ('adventures of the bailey school kids[281884]', 46),
#  ('advertising[170103]', 34),
#  ('advertising[1842]', 176),
#  ('advertising[2699]', 1043),
#  ('advertising[768024]', 1043),
#  ('aerobics[4646]', 33),
#  ('aerodynamics[226499]', 61),
#  ('aerodynamics[3074631]', 6),
#  ('aeronautics & aerospace[491336]', 44),
#  ('aeronautics & astronautics[13441]', 412),
#  ('aeronautics & space[3211]', 123),
#  ('aerospace[226498]', 1073),
#  ('aeschylus[70053]', 14),
#  ('aesop[170571]', 21),
#  ('aesthetics[11021]', 217),
#  ('aesthetics[491424]', 4),
#  ('afghanistan[16774]', 26),
#  ('afghanistan[4885]', 76),
#  ('afghanistan[639614]', 26),
#  ('africa[16703]', 562),
#  ('africa[2088]', 58),
#  ('africa[290083]', 30),
#  ('africa[290106]', 5),
#  ('africa[2918]', 35),
#  ('africa[2927]', 16),
#  ('africa[3024]', 53),
#  ('africa[3031]', 65),
#  ('africa[4762]', 1295),
#  ('africa[491410]', 12),
#  ('africa[639540]', 562),
#  ('africa[640448]', 5),
#  ('africa[733686]', 58),
#  ('african american heritage[169882]', 1),
#  ('african american[1097]', 106),
#  ('african american[297493]', 159),
#  ('african american[2980]', 18),
#  ('african american[4301]', 28),
#  ('african american[9823]', 929),
#  ('african american[9936]', 57),
#  ('african american[9974]', 172),
#  ('african americans[4867]', 524),
#  ('african canadian[1043868]', 3),
#  ('african canadian[1043898]', 1),
#  ('african-american & black[2366]', 1026),
#  ('african-american studies[11300]', 1177),
#  ('african-american studies[586120]', 7),
#  ('african-american[3095]', 461),
#  ('african[10313]', 205),
#  ('african[1049]', 10),
#  ('african[1096]', 72),
#  ('african[11813]', 73),
#  ('african[283936]', 32),
#  ('african[2978]', 74),
#  ('african[4263]', 41),
#  ('afrikaans[11497]', 2),
#  ('after effects, dimensions & persuasion[4139]', 12),
#  ('age of empires[3430]', 7),
#  ('age of empires[696952]', 7),
#  ('age of empires[768676]', 7),
#  ('agee, james[70054]', 3),
#  ('agee, jon[170572]', 14),
#  ('agents[4024]', 50),
#  ('ages 0-3 (board books)[2971]', 10),
#  ('ages 0-3[2461]', 9),
#  ('ages 0-3[266230]', 39),
#  ('ages 0-3[733822]', 9),
#  ('ages 4-8[13622261]', 89),
#  ('ages 4-8[2462]', 38),
#  ('ages 4-8[266231]', 434),
#  ('ages 4-8[2785]', 15701),
#  ('ages 4-8[2974]', 29),
#  ('ages 4-8[733824]', 38),
#  ('ages 9-12[13622271]', 72),
#  ('ages 9-12[2463]', 15),
#  ('ages 9-12[266232]', 680),
#  ('ages 9-12[2786]', 8072),
#  ('ages 9-12[2975]', 21),
#  ('ages 9-12[733826]', 15),
#  ('aging parents[11352]', 432),
#  ('aging[11354]', 219),
#  ('aging[282840]', 332),
#  ('agnosticism[12762]', 25),
#  ('agricultural engineering[226717]', 2),
#  ('agricultural sciences[226680]', 1190),
#  ('agricultural sciences[227254]', 1015),
#  ('agriculture[3208]', 45),
#  ('agriculture[491690]', 53),
#  ('agronomy[226683]', 99),
#  ('ahlberg, allan[170574]', 23),
#  ('ahlberg, janet[170573]', 16),
#  ('aids & hiv[14117]', 84),
#  ('aids[4657]', 184),
#  ('aiken, joan[14674]', 6),
#  ('aiken, joan[170575]', 15),
#  ('aiken, joan[912646]', 15),
#  ('aikido[16573]', 47),
#  ('ailey, alvin[1478]', 1),
#  ('aims & objectives[69831]', 300),
#  ('air & space[10780]', 11),
#  ('air & space[227529]', 8),
#  ('air pollution[226543]', 29),
#  ('air sports & recreation[16598]', 54),
#  ('air travel[17209]', 77),
#  ('air travel[640486]', 77),
#  ('airbrush[1878]', 16),
#  ('aix[3779]', 9),
#  ('akhmatova, anna[70056]', 3),
#  ('akira[13421781]', 6),
#  ('alabama[17265]', 11),
#  ('alabama[640540]', 11),
#  ('aladdin[184955]', 3),
#  ('alanna[184932]', 11),
#  ('alaska[14278891]', 3),
#  ('alaska[16407]', 9),
#  ('alaska[16500]', 7),
#  ('alaska[17267]', 159),
#  ('alaska[640388]', 9),
#  ('alaska[640542]', 159),
#  ('albania[4936]', 16),
#  ('albanian[11499]', 9),
#  ('albee, edward[70057]', 10),
#  ('albers, josef[1108]', 2),
#  ('albert, neil[69327]', 1),
#  ('albert, susan wittig[69328]', 12),
#  ('alberta[1091202]', 11),
#  ('alberta[1093086]', 11),
#  ('alborough, jez[170576]', 24),
#  ('albuquerque[640746]', 5),
#  ('albuquerque[67511]', 5),
#  ('alchemy[297494]', 54),
#  ('alcoholism[4719]', 167),
#  ('alcott, louisa may[170578]', 31),
#  ('alcott, louisa may[585930]', 6),
#  ('alcott, louisa may[70058]', 43),
#  ('aldiss, brian[14677]', 7),
#  ('alers, rochelle[466318]', 27),
#  ('alex anderson[5211]', 10),
#  ('alexander technique[282926]', 48),
#  ('alexander, lloyd[170579]', 47),
#  ('alexander, victoria[466326]', 11),
#  ('alexander[281922]', 13),
#  ('alexie, sherman[70059]', 14),
#  ('alexie, sherman[70863]', 7),
#  ('algebra & trigonometry[491542]', 129),
#  ('algebra[13887]', 465),
#  ('algebra[227383]', 363),
#  ('algebra[3255]', 42),
#  ('algebraic geometry[13928]', 93),
#  ('algebraic geometry[227374]', 89),
#  ('alger, horatio[70060]', 1),
#  ('algeria[4763]', 32),
#  ('algorithms[3870]', 480),
#  ('algorithms[3957]', 10),
#  ('algorithms[491298]', 78),
#  ('algren, nelson[70061]', 7),
#  ('ali, muhammad[917190]', 21),
#  ('alice[290697]', 24),
#  ('alighieri, dante[585932]', 1),
#  ('alighieri, dante[70062]', 33),
#  ('aliki[170580]', 47),
#  ('all aboard reading[282647]', 38),
#  ('all arabic books[3302731]', 13),
#  ("all children's boxed sets[13622241]", 242),
#  ('all chinese books[3302741]', 24),
#  ('all disney titles[300382]', 1),
#  ('all french books[3302761]', 266),
#  ('all german books[3302771]', 117),
#  ('all hebrew books[3302781]', 26),
#  ('all italian books[3302791]', 43),
#  ('all japanese books[3302801]', 35),
#  ('all microsoft[3070301]', 2),
#  ('all russian books[3302841]', 12),
#  ('all scholastic teaching resources[571668]', 133),
#  ('all sony pictures titles[573626]', 2),
#  ('all titles[1087714]', 1),
#  ('all titles[400126]', 1),
#  ('all works by beethoven[8965]', 2),
#  ('all works by berlioz[9596]', 1),
#  ('all works by borodin[10872]', 1),
#  ('all works by boulez[11120]', 1),
#  ('all works by brahms[11426]', 1),
#  ('all works by britten[11736]', 1),
#  ('all works by bruckner[573256]', 1),
#  ('all works by chopin[14212]', 2),
#  ('all works by copland[14949]', 1),
#  ('all works by debussy[573258]', 1),
#  ('all works by dittersdorf[17167]', 1),
#  ('all works by donizetti[17354]', 1),
#  ('all works by dowland[17520]', 1),
#  ('all works by dufay[17649]', 1),
#  ('all works by elgar[18108]', 1),
#  ('all works by franz joseph haydn[21400]', 1),
#  ('all works by gesualdo[19770]', 1),
#  ('all works by gluck[20126]', 1),
#  ('all works by handel[21068]', 1),
#  ('all works by holst[21945]', 1),
#  ('all works by j.s. bach[7616]', 2),
#  ('all works by liszt[25051]', 1),
#  ('all works by machaut[25563]', 1),
#  ('all works by mahler[25678]', 1),
#  ('all works by mendelssohn[573254]', 1),
#  ('all works by messiaen[26633]', 1),
#  ('all works by meyerbeer[26681]', 1),
#  ('all works by monteverdi[26981]', 1),
#  ('all works by offenbach[27965]', 1),
#  ('all works by part[29553]', 1),
#  ('all works by poulenc[29225]', 1),
#  ('all works by prokofiev[573674]', 1),
#  ('all works by puccini[29442]', 2),
#  ('all works by rachmaninov[574560]', 1),
#  ('all works by robert schumann[31914]', 1),
#  ('all works by rossini[573294]', 1),
#  ('all works by schoenberg[31691]', 1),
#  ('all works by schubert[31778]', 1),
#  ('all works by shostakovich[573252]', 1),
#  ('all works by sibelius[32298]', 1),
#  ('all works by strauss[33267]', 1),
#  ('all works by stravinsky[33321]', 1),
#  ('all works by szymanowski[33653]', 1),
#  ('all works by tallis[33755]', 1),
#  ('all works by tchaikovsky[33933]', 1),
#  ('all works by tippett[34239]', 1),
#  ('all works by verdi[34973]', 1),
#  ('all works by vivaldi[35210]', 1),
#  ('all works by wagner[35370]', 1),
#  ('all works by weber[35605]', 1),
#  ('all works by wolfgang amadeus mozart[27275]', 2),
#  ('all-of-a-kind family[3344]', 12),
#  ('allah[297495]', 13),
#  ('allen, charlotte vale[466324]', 2),
#  ('allen, paula gunn[70063]', 3),
#  ('allen, roger macbride[14681]', 10),
#  ('allende, isabel[565658]', 53),
#  ('allergies[282953]', 22),
#  ('allergies[4658]', 90),
#  ('allied health professions[14018]', 1955),
#  ('allied health professions[227571]', 1537),
#  ('alligators & crocodiles[2788]', 56),
#  ('allingham, margery[69329]', 2),
#  ('allison, dorothy[70064]', 5),
#  ('allston, aaron[14682]', 14),
#  ('alma-tadema, lawrence[67916]', 2),
#  ('almaas, a.h.[297922]', 12),
#  ('almanacs & yearbooks[11444]', 205),
#  ('almanacs[11445]', 98),
#  ('almanacs[172764]', 136),
#  ('almanacs[3177]', 15),
#  ('almanacs[767814]', 136),
#  ('almond, david[912648]', 12),
#  ('alphabet[11972]', 101),
#  ('alphabet[2754]', 415),
#  ('alphabet[694938]', 415),
#  ('alpine[290076]', 4),
#  ('alps[640454]', 12),
#  ('alps[68023]', 12),
#  ('alten, steve[5504]', 3),
#  ('alternate history[16275]', 116),
#  ('alternative & holistic[14038]', 1179),
#  ('alternative dispute resolution[10782]', 8),
#  ('alternative dispute resolution[227516]', 7),
#  ('alternative medicine[227583]', 692),
#  ('alternative medicine[4696]', 5226),
#  ('alternative[4755]', 50),
#  ("alzheimer's disease[14349]", 39),
#  ("alzheimer's disease[227635]", 33),
#  ("alzheimer's disease[760792]", 151),
#  ('amanda pig[3316]', 6),
#  ('amateur production[4486]', 53),
#  ('amateur radio[298642]', 3),
#  ('amateur robotics[298643]', 1),
#  ('amazing days of abby hayes[918092]', 9),
#  ('amazon.com outlet[517808]', 1779),
#  ('amazon.com stores[285080]', 123925),
#  ('amazon[640302]', 13),
#  ('amazon[67577]', 13),
#  ('amber[408724]', 2),
#  ('ambrose[173007]', 2),
#  ('amelia bedelia[3317]', 24),
#  ('amelia[281853]', 1),
#  ('america online[170140]', 16),
#  ('america[10583]', 488),
#  ('american adventure[270879]', 2),
#  ('american casebook[173497]', 118),
#  ('american diabetes association[282870]', 26),
#  ('american diaries[3345]', 9),
#  ('american girl[3346]', 89),
#  ('american government[491466]', 29),
#  ('american guides[584684]', 1),
#  ('american guides[640168]', 1),
#  ('american heart association[282871]', 34),
#  ('american literature[491406]', 13),
#  ('americana[5067]', 122),
#  ('americas[4808]', 13038),
#  ('amharic[11501]', 5),
#  ('amis, kingsley[585934]', 1),
#  ('amis, kingsley[70065]', 4),
#  ('amis, martin[70066]', 15),
#  ('amish & mennonite[4302]', 33),
#  ('amish[12406]', 25),
#  ('ammons, a.r.[70067]', 4),
#  ('amplified[172700]', 13),
#  ('amsterdam[640016]', 42),
#  ('amsterdam[67669]', 42),
#  ('analog electronics[280297]', 24),
#  ('analog electronics[3814]', 16),
#  ('analogies[280288]', 2),
#  ('analytic geometry[13930]', 32),
#  ('analytic geometry[227375]', 30),
#  ('analytic[13571]', 218),
#  ('analytic[227283]', 205),
#  ('analytical[491720]', 49),
#  ('anastasia[184933]', 13),
#  ('anastasia[281768]', 13),
#  ('anatomy & physiology[227606]', 7),
#  ('anatomy & physiology[227721]', 36),
#  ('anatomy & physiology[3209]', 170),
#  ('anatomy & physiology[491518]', 124),
#  ('anatomy & physiology[491704]', 117),
#  ('anatomy[14064]', 310),
#  ('anatomy[227595]', 306),
#  ('anatomy[720874]', 688),
#  ('anchorage[640546]', 7),
#  ('anchorage[67462]', 7),
#  ('ancient & classical[1069]', 105),
#  ('ancient civilizations[2928]', 80),
#  ('ancient[465182]', 46),
#  ('ancient[4873]', 2336),
#  ('andalusia[640050]', 13),
#  ('andalusia[67683]', 13),
#  ('andersen, hans christian[170581]', 34),
#  ('andersen, susan[12843]', 11),
#  ('anderson, c.w.[170582]', 13),
#  ('anderson, catherine[12845]', 12),
#  ('anderson, kevin j.[585888]', 10),
#  ('anderson, laurie halse[912650]', 20),
#  ('anderson, m. t.[5528]', 1),
#  ('anderson, m.t.[912652]', 4),
#  ('anderson, poul[14686]', 14),
#  ('anderson, sherwood[70068]', 10),
#  ('anderson-dargatz, gail[10328]', 2),
#  ('andorra[16919]', 2),
#  ('andorra[639834]', 2),
#  ('andrews, v. c.[5533]', 58),
#  ('anesthesia[14193]', 8),
#  ('anesthesia[227642]', 7),
#  ('anesthesiology[14307]', 153),
#  ('anesthesiology[227607]', 7),
#  ('anesthesiology[227686]', 153),
#  ('angelico, fra[1111]', 3),
#  ('angelology[297489]', 115),
#  ('angelou, maya[585926]', 14),
#  ('angelou, maya[70069]', 47),
#  ('angelou, maya[70867]', 26),
#  ('angelou, maya[9824]', 49),
#  ('angels[297524]', 202),
#  ('angels[518452]', 4),
#  ('anger management[282923]', 54),
#  ('anglican[12408]', 44),
#  ('angola[4764]', 11),
#  ('animal ark[918076]', 46),
#  ('animal care & pets[5043]', 5877),
#  ('animal hospital[918080]', 6),
#  ('animal husbandry[3048971]', 93),
#  ('animal husbandry[3048981]', 79),
#  ('animal rights[14454]', 97),
#  ('animal science[491692]', 12),
#  ('animal tracks[290103]', 11),
#  ('animals[1038360]', 16),
#  ('animals[13474]', 2110),
#  ('animals[13622281]', 33),
#  ('animals[169044]', 1),
#  ('animals[2464]', 19),
#  ('animals[2787]', 9476),
#  ('animals[290347]', 1),
#  ('animals[502888]', 9),
#  ('animals[515786]', 15),
#  ('animals[586096]', 104),
#  ('animals[642264]', 8),
#  ('animals[733828]', 19),
#  ('animals[918074]', 52),
#  ('animation & 3-d design[403684]', 4),
#  ('animation[169045]', 1),
#  ('animation[170107]', 60),
#  ('animation[3920]', 82),
#  ('animorphs[3303]', 40),
#  ('anne of green gables[3306]', 45),
#  ('annie bananie[3318]', 6),
#  ("anno's math games[281841]", 11),
#  ('anno, mitsumasa[170583]', 13),
#  ('annotations & citations[227140]', 1),
#  ('annotations & citations[227502]', 1),
#  ('annoyances[69864]', 4),
#  ('annuals[1843]', 42),
#  ('annuals[5249]', 31),
#  ('anonymous[565708]', 4),
#  ('anselm[173008]', 3),
#  ('anshaw, carol[70070]', 3),
#  ('antarctica[17201]', 46),
#  ('antarctica[640356]', 46),
#  ('antebellum[4855]', 136),
#  ('antennas & radar[13801]', 86),
#  ('anthems[67107]', 1),
#  ('anthologies[10137]', 628),
#  ('anthologies[10250]', 622),
#  ('anthologies[10303]', 737),
#  ('anthologies[10459]', 92),
#  ('anthologies[12827]', 138),
#  ('anthologies[16193]', 139),
#  ('anthologies[16277]', 169),
#  ('anthologies[2161]', 138),
#  ('anthologies[2984]', 216),
#  ('anthologies[2996]', 14),
#  ('anthologies[524202]', 115),
#  ('anthologies[5434]', 172),
#  ('anthony, mark[14688]', 9),
#  ('anthony, piers[14690]', 136),
#  ('anthropology[11233]', 3366),
#  ('anthropology[491448]', 128),
#  ...]

# %% [markdown]
# From the above we do see a lot of repetitive category names. The only difference between them is the category id inside []. The categories should get consolidated in order to reduce the redundancy.
#
# A consolidated database of category entries would reduce the redundancy by:

# %%
len(set([x[0].split('[')[0] for x in sorted_categories_by_key[1:]]))/len(categories_count)
# Out:
# 0.5744438488340927

# %%
len([x for x in sorted_categories_by_val if x[1] < 4])/len(set([x[0].split('[')[0] for x in sorted_categories_by_key[1:]]))
# Out:
# 0.2948792721334422

# %% [markdown]
# Another approach is to consider only the last category item in the category entry (hierarchical chain of categories) that we have already retrieved in *categories_entr_count*:

# %%
len(categories_entr_count)
# Out:
# 12853

# %%
categories_entr_count
# Out:
# {'preaching[12368]': 364,
#  'sermons[12370]': 315,
#  'wicca[12484]': 490,
#  'witchcraft[12486]': 527,
#  'general[5144]': 5108,
#  'new testament[12159]': 604,
#  'discipleship[12335]': 343,
#  'life application[572080]': 90,
#  'new testament[572082]': 1782,
#  'general[572094]': 2067,
#  'prayerbooks[12470]': 276,
#  'business[297488]': 270,
#  'photo essays[2082]': 2748,
#  'general[4870]': 1983,
#  'general[4993]': 451,
#  'urban[11296]': 513,
#  'photo essays[733676]': 2748,
#  'general[10716]': 760,
#  'criminology[11005]': 868,
#  'general[11083]': 7715,
#  'u.s.[11117]': 1253,
#  'bread[4197]': 187,
#  'general[10213]': 3093,
#  'history & theory[11086]': 1633,
#  'cultural[11235]': 2243,
#  'general[4701]': 1404,
#  'general[14046]': 508,
#  'general[227584]': 389,
#  'jp-unknown2[1061350]': 2833,
#  'herbs, spices & condiments[4211]': 158,
#  'general[4233]': 6528,
#  'diabetic & sugar-free[4318]': 134,
#  'low fat[4323]': 264,
#  'general[4628]': 842,
#  'low carbohydrate[4639]': 99,
#  'low sugar[4642]': 51,
#  'low-fat diet[282849]': 356,
#  'low carb[10924671]': 99,
#  'history & criticism[16203]': 106,
#  'history & criticism[16288]': 90,
#  'united states[2160]': 631,
#  'general[2218]': 801,
#  'bogosian, eric[70116]': 6,
#  'naval[5018]': 474,
#  'general[465308]': 1868,
#  'naval[465318]': 287,
#  'management[2683]': 3953,
#  'general[3731]': 150,
#  'general[13756]': 909,
#  'general[13813]': 1022,
#  'engineering economics[226701]': 34,
#  'general[657762]': 8660,
#  'management[768000]': 3955,
#  'comics & graphic novels[3014]': 867,
#  'marvel[4400]': 267,
#  'fantasy[17468]': 1227,
#  'superheroes[3825121]': 472,
#  'general[14407]': 449,
#  'general[227709]': 372,
#  'contemporary[10129]': 11446,
#  'general[10466]': 4912,
#  'general[605116]': 6603,
#  'mystery[2304]': 570,
#  'radio shows[2312]': 85,
#  'general broadcasting[4566]': 175,
#  'british detectives[10461]': 593,
#  'sherlock holmes[10477]': 138,
#  'general[284551]': 36,
#  'doyle, arthur conan[287265]': 11,
#  'doyle, sir arthur conan[585790]': 16,
#  'general[658010]': 5105,
#  'elections[10763]': 266,
#  'history[11336]': 502,
#  'stories[3002]': 1138,
#  'picture books[170061]': 4173,
#  'general[170062]': 11439,
#  'classics[10127]': 5648,
#  'lesbian studies[11308]': 335,
#  'faith[12339]': 440,
#  'marriage[69722]': 510,
#  'assessment & diagnosis[14195]': 152,
#  'pediatric & neonatal[14231]': 103,
#  'general[14392]': 658,
#  'assessment & diagnosis[227643]': 134,
#  'pediatrics[227660]': 97,
#  'general[13788]': 829,
#  'advanced mechanics[226500]': 965,
#  'mechanics[226524]': 965,
#  'jp-unknown1[1061348]': 3447,
#  'hospitality, travel & tourism[2636]': 332,
#  'south[4314]': 235,
#  'dining[17035]': 447,
#  'general[17248]': 75,
#  'dining[640094]': 447,
#  'general[640524]': 75,
#  'hospitality, travel & tourism[767918]': 332,
#  'history[4232]': 221,
#  'professional[4254]': 111,
#  'general[4307]': 435,
#  'middle atlantic[4309]': 41,
#  'science fiction, fantasy, & magic[3017]': 3286,
#  'science fiction[17470]': 1092,
#  't.witches[918066]': 9,
#  'twins[1084244]': 131,
#  'fiction[2813]': 875,
#  'humorous[3003]': 3894,
#  'general[16952]': 337,
#  'general[67620]': 90,
#  'general[639932]': 337,
#  'general[639938]': 90,
#  'general[2566]': 568,
#  'human resources & personnel management[2637]': 1325,
#  "manager's guides to computing[3700]": 523,
#  'occupational & organizational[11189]': 187,
#  'secrets of success[767772]': 568,
#  'human resources & personnel management[767920]': 1325,
#  "manager's guides to computing[768660]": 523,
#  'popular fiction[400096]': 895,
#  'general[5335]': 300,
#  'parent & adult child[11390]': 119,
#  'memoirs[3048891]': 995,
#  'reference[14237]': 153,
#  'hospice care[14258]': 58,
#  'reference[227663]': 147,
#  'whitman, walt[9924]': 27,
#  '20th century[9972]': 1871,
#  'general[10259]': 3817,
#  'united states[10287]': 1980,
#  'whitman, walt[70700]': 24,
#  '19th century[170082]': 538,
#  'general[725800]': 1980,
#  'active server pages[3601]': 182,
#  'general[3959]': 635,
#  'general[171114]': 3345,
#  'eschatology[172812]': 306,
#  'general[657764]': 1425,
#  'general[10001]': 294,
#  'literature guides[11399]': 176,
#  'classics[17445]': 313,
#  'spine-chilling horror[3018]': 929,
#  'stine, r. l.[9222]': 201,
#  'general[170063]': 8008,
#  'stine, r. l.[281800]': 202,
#  'monsters[513092]': 241,
#  'popular culture[3011]': 1475,
#  'mysteries, espionage, & detectives[3016]': 1657,
#  'james, del[7312]': 13,
#  'scooby-doo mystery[281836]': 65,
#  'scooby doo mysteries[918102]': 33,
#  'general[12354]': 1538,
#  'ministry[12364]': 672,
#  'pentecostal[12438]': 347,
#  'love & romance[4733]': 951,
#  'folklore & mythology[11256]': 831,
#  'general[11289]': 11779,
#  'magic[12710]': 530,
#  'occultism[12714]': 209,
#  'general[2612]': 18436,
#  'financial planning[2721]': 264,
#  'retirement planning[2731]': 143,
#  'retirement planning[11360]': 72,
#  'general[767880]': 18438,
#  'financial planning[768062]': 264,
#  'retirement planning[768068]': 143,
#  'action & adventure[2967]': 4061,
#  'fiction[3154]': 1209,
#  'betsy & tacy[3307]': 12,
#  'essays[4464]': 429,
#  'general[4466]': 2727,
#  'hackers[3648]': 133,
#  'security[4003]': 374,
#  'hackers[768618]': 133,
#  'security[768636]': 374,
#  'birds[290081]': 536,
#  'rocky mountains[290094]': 18,
#  'general[290110]': 643,
#  'reference[764418]': 333,
#  'history & criticism[4511]': 1245,
#  'appreciation & history[491372]': 15,
#  'general[491388]': 44,
#  'europe[491414]': 89,
#  'nonfiction[3066]': 23,
#  'spanish[69810]': 495,
#  'bebes a 3 años[301738]': 95,
#  'school & education[3192]': 163,
#  'medical[2423]': 273,
#  'general[4635]': 192,
#  'nutrition[14243]': 189,
#  'general[14367]': 357,
#  'biografías y memorias[301733]': 131,
#  'general[465674]': 522,
#  'fiction[3073]': 765,
#  'general[13857]': 1461,
#  'history[13942]': 1437,
#  'general[14183]': 1245,
#  'history[14185]': 331,
#  'biographies[3103]': 18,
#  'christian[3114]': 995,
#  'ages 4-8[266231]': 434,
#  'jesus[266237]': 134,
#  'epistemology[11035]': 339,
#  'general[11043]': 5391,
#  'modern[11057]': 1242,
#  'phenomenology[11063]': 100,
#  'historiography[4988]': 273,
#  'general[1205142]': 225,
#  'human geography[11272]': 284,
#  "children's studies[3048861]": 180,
#  'general[4413]': 166,
#  'general[4435]': 2553,
#  'tarot[12659]': 333,
#  'general[3049]': 1461,
#  'ages 9-12[266232]': 680,
#  'seventh heaven[280275]': 22,
#  'company profiles[2542]': 128,
#  'management science[2684]': 284,
#  'general[2737]': 758,
#  'company profiles[767746]': 128,
#  'management science[768002]': 284,
#  'general[768092]': 758,
#  'reference[4498]': 244,
#  'reference[4574]': 75,
#  'americana[5067]': 122,
#  'art[11716]': 157,
#  'encyclopedias[11726]': 50,
#  'pop culture[11751]': 51,
#  'television[11757]': 20,
#  'patent, trademark & copyright[10960]': 120,
#  'general[10963]': 404,
#  'reference[10975]': 282,
#  'authorship[11892]': 272,
#  'general[12024]': 890,
#  'patent, trademark & copyright[227490]': 109,
#  'reference[227499]': 265,
#  'african american[4301]': 28,
#  'general[11334]': 2240,
#  'general[408268]': 13701,
#  'general[2375]': 12241,
#  'general[12746]': 225,
#  'general[12813]': 3340,
#  'easwaran, eknath[297948]': 29,
#  'twain, mark[9920]': 156,
#  'general[284637]': 159,
#  'paperback[285693]': 97,
#  'breastfeeding[11404]': 60,
#  'books[548878]': 53,
#  'breastfeeding books[692272]': 53,
#  'general[2253]': 1382,
#  'general[2297]': 1262,
#  'english (all)[11486]': 2387,
#  'polish[11571]': 27,
#  'polish[11847]': 29,
#  'spy stories & tales of intrigue[10493]': 1173,
#  'new england[17242]': 318,
#  'new england[640518]': 318,
#  'general[9894]': 2032,
#  'united states[10301]': 1274,
#  'corporate finance[2607]': 479,
#  'general[2747]': 622,
#  'corporate finance[767870]': 480,
#  'general[768106]': 622,
#  'general[11606]': 1177,
#  'slang & idioms[11619]': 165,
#  'history of technology[14637]': 1235,
#  'general[12341]': 5242,
#  'inspirational[12422]': 188,
#  'finance & investing[2608]': 1420,
#  'options[2672]': 239,
#  'general[2722]': 782,
#  'general[266120]': 1296,
#  'finance & investing[767872]': 1420,
#  'options[767988]': 239,
#  'general[768064]': 784,
#  'general[13999]': 269,
#  'general[227561]': 205,
#  'general[10485]': 1897,
#  'suspense[10495]': 2540,
#  'general[69728]': 569,
#  'political[171129]': 300,
#  'logic & brain teasers[4436]': 134,
#  'puzzles[4439]': 301,
#  'general[10114]': 1044,
#  'eliot, t. s.[173057]': 27,
#  'general[10896]': 148,
#  'property[10966]': 74,
#  'property[227458]': 73,
#  'general[10635]': 8759,
#  'lesson planning[10646]': 828,
#  'assessment[69832]': 474,
#  'finance[69836]': 128,
#  'standards[172766]': 72,
#  'pedagogy[266137]': 2192,
#  'general[13924]': 904,
#  'marriage & family[11291]': 412,
#  'general[11383]': 680,
#  'motherhood[11388]': 449,
#  'ophthalmology[14375]': 204,
#  'otolaryngology[14377]': 105,
#  'ophthalmology[227196]': 179,
#  'otolaryngology[227691]': 103,
#  'general[4679]': 562,
#  'infants[11410]': 288,
#  'general[11423]': 2277,
#  'infant-development books[692282]': 255,
#  'parenting books[692288]': 2029,
#  'pregnancy & childbirth books[692292]': 479,
#  'mozart, wolfgang amadeus[1564]': 34,
#  'historical[10177]': 3279,
#  'mozart, wolfgang amadeus[917210]': 17,
#  'nonfiction[2806]': 51,
#  'nonfiction[2855]': 89,
#  'web graphics[3539]': 1402,
#  'web site design[3565]': 1410,
#  'image composer[4154]': 1,
#  'general[301149]': 2075,
#  'bowling[16539]': 19,
#  'general[11086921]': 7059,
#  'general[2669]': 1693,
#  'general[767982]': 1693,
#  'west, benjamin[1459]': 2,
#  'series[10475]': 1608,
#  'women sleuths[10480]': 1935,
#  'fiction[3228]': 201,
#  'magic school bus[3324]': 41,
#  'cole, joanna[170637]': 100,
#  'degen, bruce[170651]': 61,
#  'no ficción[301737]': 297,
#  '4 a 8 años[301739]': 631,
#  'general[285760]': 157,
#  'paperback[285765]': 56,
#  'general[735744]': 1311,
#  'communism & socialism[11089]': 297,
#  'radical thought[11091]': 185,
#  'general[2765]': 1065,
#  'crews, donald[170644]': 33,
#  'general[694944]': 1066,
#  'nonfiction[2810]': 160,
#  'general[3049241]': 3758,
#  'general[171130]': 670,
#  'adobe indesign[295224]': 10,
#  'general[3259]': 402,
#  'general[1099196]': 433,
#  'mathematics[1099204]': 139,
#  'ballroom[1476]': 14,
#  'general[1514]': 145,
#  'popular[1518]': 17,
#  'reference[1519]': 47,
#  'literary[10132]': 5588,
#  'greeley, andrew[69448]': 18,
#  'medical history & records[14010]': 130,
#  'practice management & reimbursement[14012]': 145,
#  'general[14276]': 747,
#  'general[14621]': 747,
#  'medical history & records[227567]': 115,
#  'practice management & reimbursement[227568]': 122,
#  'general[227671]': 587,
#  'political parties[11107]': 212,
#  'practical politics[11109]': 533,
#  'leadership[2682]': 1744,
#  'entrepreneurship[2745]': 3233,
#  'entrepreneurship[767820]': 3233,
#  'leadership[767998]': 1744,
#  'personal growth[2263]': 355,
#  'psychology[2265]': 323,
#  'general[2321]': 856,
#  'inspiration & philosophy[2322]': 655,
#  'motivational[4744]': 1220,
#  'personal transformation[4745]': 1449,
#  'inspirational[12817]': 3822,
#  'general[284594]': 55,
#  'vanzant, iyanla[287214]': 15,
#  'youth ministry[12374]': 449,
#  'general[12526]': 407,
#  'church institutions & organizations[12358]': 801,
#  "women's issues[3043241]": 681,
#  'inspirational[12297]': 661,
#  'ecology[14463]': 487,
#  'general[5039]': 940,
#  'basketball[2448]': 63,
#  'general[2450]': 761,
#  'general[193913]': 289,
#  'college & university[193914]': 60,
#  'chemistry[3216]': 72,
#  'ghosts[9810]': 110,
#  'general[12617]': 1363,
#  'supernatural[12725]': 174,
#  'unexplained mysteries[12729]': 392,
#  'collections & readers[524198]': 378,
#  'general[4866]': 1105,
#  'physical & theoretical[13588]': 281,
#  'thermodynamics[14587]': 165,
#  'thermodynamics[226514]': 50,
#  'physical & theoretical[227289]': 272,
#  'thermodynamics[227418]': 86,
#  'family activities[11365]': 283,
#  'general[5421]': 356,
#  'jewish life[12563]': 468,
#  'ritual[12771]': 814,
#  'general[16199]': 3386,
#  'general[284611]': 72,
#  'paperback[285629]': 52,
#  'french[11533]': 74,
#  'french[11825]': 412,
#  'vocabulary[12011]': 205,
#  'general[10198]': 699,
#  'general[12458]': 2168,
#  'angelology[297489]': 115,
#  'angels[297524]': 202,
#  'religious warfare[893520]': 145,
#  'anthologies[2984]': 216,
#  'historical[10470]': 500,
#  'general[299951]': 56,
#  'paperback[299953]': 37,
#  'general[5276]': 2254,
#  'house plants[5283]': 60,
#  'entomology[226690]': 135,
#  'entomology[227271]': 131,
#  'general[1066]': 1993,
#  'general[585494]': 2107,
#  'general[12667]': 4500,
#  'spiritualism[12723]': 282,
#  'therapy[4712]': 33,
#  'rheumatology[14371]': 164,
#  'rheumatology[227213]': 146,
#  'general[297481]': 298,
#  'general[298657]': 1818,
#  'general[11268]': 1958,
#  'tribal & ethnic[12775]': 162,
#  'social scientists & psychologists[2427]': 124,
#  'gay[2440]': 92,
#  'general[2441]': 248,
#  'general[11237]': 953,
#  'adventurers & explorers[171115]': 117,
#  'general[10307]': 1793,
#  'toefl & toeic[11655]': 93,
#  'toefl[11932]': 87,
#  'general[2393]': 1631,
#  'presidents & heads of state[2418]': 358,
#  'revolutionary[4990]': 75,
#  'holocaust[4994]': 450,
#  'discrimination & racism[11249]': 527,
#  'block, francesca lia[912672]': 19,
#  'diagnosis[14249]': 434,
#  'communicable diseases[14337]': 215,
#  'epidemiology[14339]': 187,
#  'communicable diseases[227207]': 187,
#  'epidemiology[227208]': 172,
#  'physical examination[227667]': 373,
#  'consciousness & thought[11023]': 562,
#  'general[13872]': 719,
#  'quality control[13799]': 231,
#  'sports[4481]': 236,
#  'self help[12444]': 523,
#  'leadership[12343]': 313,
#  'comparative religion[12783]': 1072,
#  'psychology[12803]': 191,
#  'economic history[2589]': 439,
#  'creativity & genius[11160]': 130,
#  'business history[767760]': 439,
#  'general[4738]': 5755,
#  'pain management[282848]': 149,
#  'testing[11709]': 341,
#  'writing skills[12053]': 641,
#  'general[408252]': 1275,
#  'study guides[1099190]': 511,
#  'study & teaching[1836]': 249,
#  'criticism[10825731]': 741,
#  'mammals[13499]': 419,
#  'mind-body connection[282929]': 35,
#  'general[4666]': 599,
#  'health care delivery[14001]': 593,
#  'public health[14014]': 419,
#  'health care delivery[227562]': 522,
#  'public health[227569]': 377,
#  'hornby, nick[70339]': 10,
#  'general[524200]': 2945,
#  'love, sex & marriage[4472]': 153,
#  'political[4474]': 159,
#  'satire, general[4478]': 364,
#  'conspiracy theories[10552]': 295,
#  'leadership[11105]': 304,
#  'reference[11111]': 204,
#  'all scholastic teaching resources[571668]': 133,
#  'school safety & violence[3048951]': 7,
#  "thomas a' kempis[173168]": 13,
#  'general[2354]': 348,
#  'science & technology[2362]': 198,
#  'nonfiction[2791]': 29,
#  'nonfiction[3265]': 144,
#  'ecology[1099200]': 34,
#  'emigration & immigration[10864]': 43,
#  'emigration & immigration[227435]': 39,
#  'european[1100]': 682,
#  'general[1864]': 994,
#  'animals[2464]': 19,
#  'general[2472]': 40,
#  'travel[2524]': 21,
#  'bargain travel books[605016]': 20,
#  'travel books[661972]': 21,
#  'animals[733828]': 19,
#  'general[733844]': 40,
#  'travel[733946]': 21,
#  'general[2713]': 437,
#  'general[768050]': 439,
#  'study & teaching[13985]': 113,
#  'general[491356]': 38,
#  'general[491360]': 369,
#  'general[573248]': 1198,
#  'sales[2245]': 63,
#  'sales[768154]': 63,
#  'mcse[3456]': 297,
#  'coriolis[3460]': 147,
#  'general[3805]': 386,
#  'sql server[3806]': 151,
#  'database management systems[4084]': 500,
#  'windows - general[4130]': 1039,
#  'general[407484]': 1815,
#  'windows - general[768188]': 1039,
#  'fiber optics[13709]': 54,
#  'waves & wave mechanics[14601]': 102,
#  'waves & wave mechanics[227420]': 96,
#  'general[266173]': 169,
#  'mapplethorpe, robert[1323]': 7,
#  'general[2050]': 1178,
#  'portraits[2084]': 627,
#  'general[733568]': 1179,
#  'mapplethorpe, robert[733596]': 7,
#  'portraits[733680]': 627,
#  'ecology[13529]': 615,
#  'ecology[227280]': 589,
#  'origami[5159]': 132,
#  'christianity[2319]': 309,
#  'marriage[4734]': 780,
#  'dobson, james[173050]': 67,
#  'melville, herman[9908]': 66,
#  'book notes[11630]': 389,
#  'general[284630]': 60,
#  'paperback[285686]': 42,
#  'new experiences[3059]': 333,
#  'african-american[3095]': 461,
#  'asian & asian american[3096]': 132,
#  'new experiences[3134]': 357,
#  'mead, alice[912804]': 5,
#  'bullies[1084222]': 60,
#  'alexie, sherman[70059]': 14,
#  'alexie, sherman[70863]': 7,
#  'sheldon, sidney[70610]': 36,
#  'acting & auditioning[2155]': 395,
#  'directories[170941]': 979,
#  'general[465222]': 991,
#  'general[14445]': 592,
#  'general[227720]': 591,
#  'general[16485]': 212,
#  'general[16490]': 720,
#  'guitar[1767]': 1006,
#  'popular[1824]': 527,
#  'general[4510]': 903,
#  'electromagnetism[226697]': 191,
#  'electromagnetic theory[226995]': 88,
#  'total quality management[2696]': 183,
#  'total quality management[768018]': 183,
#  'general & reference[13579]': 488,
#  'general[13654]': 442,
#  'general & reference[227285]': 456,
#  'america[10583]': 488,
#  'breeds[5050]': 654,
#  'general[5056]': 2152,
#  'language experience approach[10618]': 295,
#  'phonetics & phonics[11990]': 113,
#  'adult & continuing education[69822]': 172,
#  'reading[541646]': 784,
#  'aviation[5012]': 531,
#  'united states[491422]': 143,
#  'modern[1083]': 712,
#  'religious[1873]': 192,
#  'glass & glassware[5145]': 201,
#  'reference[5172]': 265,
#  'anthologies[10137]': 628,
#  'anthologies[16277]': 169,
#  'general[16282]': 4803,
#  'general[467958]': 213,
#  'travel[3392]': 17,
#  'family travel[17215]': 224,
#  'family travel[640492]': 224,
#  'power tools[5385]': 58,
#  'creech, sharon[912698]': 19,
#  'continental european[2163]': 224,
#  'poetry, drama & short stories[2299]': 144,
#  'lesbian[10173]': 248,
#  'lesbian[10274]': 20,
#  'gay & lesbian[586106]': 8,
#  'tremblay, michel[1044286]': 2,
#  'policy & current events[2550]': 724,
#  'development & growth[2585]': 625,
#  'economic policy & development[2588]': 928,
#  'international[2594]': 517,
#  'general[2662]': 710,
#  'relations[11097]': 2192,
#  'policy & current events[767752]': 724,
#  'development & growth[767830]': 625,
#  'international[767842]': 517,
#  'economic policy & development[767860]': 928,
#  'general[767970]': 710,
#  'board books[2778]': 1491,
#  'board books[692220]': 1425,
#  'criticism[1002]': 429,
#  'general[1005]': 4334,
#  'popular culture[4556]': 1325,
#  'urban & land use planning[720868]': 366,
#  'nonfiction[3223]': 182,
#  'general[16403]': 613,
#  'instructional[16472]': 333,
#  'general[640384]': 614,
#  'new business enterprises[2751]': 194,
#  'new business enterprises[768114]': 194,
#  'self-esteem[4746]': 678,
#  'cunningham, scott[297941]': 19,
#  'general[5085]': 2120,
#  'sports memorabilia (besides cards)[5117]': 46,
#  'general[281387]': 580,
#  'general[5023]': 742,
#  'fiction[2844]': 228,
#  'general[547894]': 220,
#  'level 1 (paperback)[547902]': 58,
#  'military & spies[2424]': 751,
#  'general[5014]': 2558,
#  'united states civil war[465246]': 253,
#  'general[465250]': 1134,
#  'personal narratives[465256]': 44,
#  'general[886496]': 751,
#  'microsoft visual c++[3962]': 56,
#  'tutorials[3966]': 81,
#  'war & peace[10590]': 186,
#  'general[11175]': 8064,
#  'hemingway, ernest[9900]': 61,
#  'general[284625]': 40,
#  'hemingway, ernest[287242]': 4,
#  'classics[1038388]': 103,
#  'psychology[11141]': 578,
#  'general[11439]': 381,
#  'mentally disabled[69848]': 44,
#  "autism & asperger's syndrome[282950]": 186,
#  'special needs children[282964]': 495,
#  'democracy[10761]': 470,
#  'general[2628]': 1258,
#  'general[266118]': 1149,
#  'general[767890]': 1261,
#  'general[3435]': 568,
#  'video & electronic games[4453]': 588,
#  'general[696962]': 568,
#  'general[768686]': 568,
#  'video games[1099188]': 606,
#  'video games[1099384]': 606,
#  'video games[1101348]': 606,
#  'state & local[4872]': 2868,
#  'miller, henry[70473]': 14,
#  'literature & fiction[13622501]': 79,
#  'adventure & thrillers[17416]': 705,
#  'general[265004]': 1169,
#  'korman, gordon[1044026]': 31,
#  'political[2397]': 919,
#  'women[2445]': 3043,
#  'public affairs & administration[10767]': 413,
#  'health & nutrition[11425]': 104,
#  'general[172722]': 3246,
#  'general[3111]': 516,
#  'general[3115]': 238,
#  'my first bible[290719]': 11,
#  'james, p.d.[69492]': 33,
#  'performing arts[876684]': 43,
#  'general[3610]': 648,
#  'business law[2733]': 375,
#  'general[10778]': 362,
#  'general[227437]': 328,
#  'general[227455]': 325,
#  'business law[768088]': 375,
#  'mystery[400106]': 73,
#  'brown, dan[14055391]': 9,
#  'general[4385]': 675,
#  'general[4389]': 1646,
#  'shonen (boys)[13421161]': 81,
#  'rurouni kenshin[13421901]': 4,
#  'british[10305]': 680,
#  'antiques[2493]': 4,
#  'antiques[733886]': 4,
#  'coloring books[3374]': 777,
#  'stress management[4747]': 439,
#  'time management[4750]': 43,
#  'general[284578]': 41,
#  'paperback[285701]': 21,
#  'general[12707]': 879,
#  'general[14486]': 749,
#  'brown, tom[297929]': 5,
#  'general[4953]': 740,
#  'manic depression[4693]': 81,
#  'pathologies[11192]': 469,
#  'general[224941]': 735,
#  'general[227702]': 717,
#  'general[491502]': 276,
#  'general[491530]': 454,
#  'police procedurals[10482]': 987,
#  'environmental science[13598]': 1170,
#  'general[13745]': 440,
#  'environmental science[227422]': 1091,
#  'labor & industrial relations[2595]': 543,
#  'labor & industrial relations[11101]': 342,
#  'policy[266131]': 445,
#  'labor & industrial relations[767862]': 543,
#  'fiction[2850]': 505,
#  'minority studies[11310]': 201,
#  'negocios e inversiones[301734]': 225,
#  'couples & family therapy[11154]': 306,
#  'social psychology & interactions[11223]': 494,
#  'theology[12597]': 195,
#  'web multimedia[3564]': 225,
#  'internet publishing[3710]': 815,
#  'general[502148]': 174,
#  'general[768294]': 174,
#  'piano[1726]': 53,
#  'advertising[2699]': 1043,
#  'advertising[768024]': 1043,
#  'preschool & kindergarten[69824]': 466,
#  'physical education[69841]': 166,
#  'general[2307]': 914,
#  'authors[2330]': 1922,
#  'general[2383]': 408,
#  "o'brien, edna[70498]": 12,
#  'arts & literature[586076]': 48,
#  'ethnic & national[586078]': 35,
#  'general[586082]': 299,
#  'historical[586084]': 55,
#  'joyce, james[917198]': 11,
#  'general[224692]': 440,
#  'star-gazing[13456]': 133,
#  'internet newcomer[4111]': 191,
#  'pcs[69774]': 164,
#  'internet newcomer[768572]': 191,
#  'entertainers[2344]': 1134,
#  'movie directors[2345]': 113,
#  'direction & production[4491]': 555,
#  'adventure[16273]': 956,
#  'general[265642]': 397,
#  'deep space nine[265643]': 39,
#  'picture books[2784]': 1160,
#  'fiction[3164]': 476,
#  'hard-boiled[10468]': 480,
#  'fiction[3161]': 336,
#  'liszt, franz[1561]': 6,
#  'general[1620]': 582,
#  'general[2334]': 116,
#  'general[2338]': 706,
#  'acupuncture & acupressure[4698]': 218,
#  'reflexology[4710]': 56,
#  'general[4674]': 699,
#  "maternity, perinatal & women's health[14217]": 121,
#  "women's health, obstetrics & gynecology[227653]": 107,
#  'maternity & nursing books[692284]': 93,
#  'financial[2627]': 202,
#  'capital generation[2744]': 135,
#  'financial[767888]': 202,
#  'capital generation[768102]': 135,
#  'boating[16649]': 438,
#  'general[16660]': 316,
#  'excursion guides[290125]': 37,
#  'jurisprudence[10900]': 129,
#  'law enforcement[10907]': 427,
#  'penology[11015]': 196,
#  'law enforcement[227470]': 368,
#  'jurisprudence[227510]': 122,
#  'american government[491466]': 29,
#  'general[491508]': 334,
#  'reference[491516]': 245,
#  'networking[3493]': 956,
#  'networks[3747]': 1094,
#  'general[3783]': 654,
#  'unix[3866]': 27,
#  'networking[491302]': 243,
#  'operating systems[491312]': 81,
#  'programming languages[491314]': 282,
#  'general[495380]': 2289,
#  "complete idiot's guide: applications[4120]": 21,
#  'general[291371]': 334,
#  "complete idiot's guide: applications[727860]": 21,
#  'software design[4015]': 806,
#  'software design[727874]': 806,
#  'software design[768650]': 806,
#  'interpersonal relations[4732]': 1601,
#  'mate seeking[4735]': 503,
#  'general[67612]': 153,
#  'general[639896]': 153,
#  'greece[4880]': 313,
#  'general[465278]': 632,
#  'herbal remedies[4703]': 584,
#  'insight pocket guide[17094]': 72,
#  'west south central[17252]': 158,
#  'new orleans[17335]': 56,
#  'insight pocket guide[640190]': 72,
#  'west south central[640528]': 158,
#  'new orleans[640684]': 56,
#  'composition & creative writing[3183]': 111,
#  'general[3203]': 163,
#  'circuits[13698]': 415,
#  'general[13711]': 2047,
#  'semiconductors[13725]': 179,
#  'systems analysis & design[602672]': 290,
#  'grammar[11981]': 456,
#  'linguistics[11986]': 1280,
#  'lesbian[301808]': 95,
#  'general[4752]': 544,
#  'general[4757]': 372,
#  'general[13533]': 1181,
#  'research[13640]': 255,
#  'methodology & statistics[13845]': 252,
#  'general[227272]': 1114,
#  'general[12551]': 388,
#  'nonfiction[3276]': 36,
#  'israel[5001]': 424,
#  'other[12116]': 418,
#  'history of religion[12559]': 218,
#  'general[4616]': 747,
#  'garden design[5271]': 474,
#  'general[10828091]': 396,
#  'atlases[11450]': 453,
#  'maps[11453]': 679,
#  'montana[17351]': 53,
#  'montana[640726]': 53,
#  'atlases[640896]': 453,
#  'maps[640900]': 679,
#  'beer[4221]': 84,
#  'general[16548]': 324,
#  'general[17271]': 151,
#  'cycling[290116]': 209,
#  'cycling[640370]': 209,
#  'general[640552]': 151,
#  'bernstein, leonard[1544]': 2,
#  'musical[2356]': 113,
#  'general[2886]': 136,
#  'botany[13521]': 443,
#  'flowers[13550]': 251,
#  'general[13552]': 349,
#  'botany[227279]': 417,
#  'flowers[290099]': 118,
#  'general[11960]': 129,
#  'strings[1770]': 210,
#  'instruction & study[4544]': 643,
#  'general[12295]': 1416,
#  'feminist[172813]': 243,
#  'general[3879]': 287,
#  'general[3891]': 537,
#  'machine learning[3894]': 44,
#  'robotics[3897]': 103,
#  'agents[4024]': 50,
#  'robotics[13794]': 208,
#  'human vision & language systems[280291]': 242,
#  'wiggs, susan[13332]': 19,
#  'general[13361]': 4206,
#  'general[745662]': 2244,
#  'taoism[11031]': 228,
#  'taoism[12757]': 210,
#  'general[12166]': 462,
#  'interpersonal relations[1038324]': 30,
#  'self help[1038378]': 250,
#  'arabic[11504]': 108,
#  'arabic[11815]': 105,
#  'general[12626]': 320,
#  'hubbard, l. ron[15378]': 19,
#  'asian[1099]': 347,
#  'clip art[1840]': 369,
#  'general[1853]': 834,
#  'pictorial[10529]': 216,
#  'general[11947]': 2566,
#  'foreign[171102]': 151,
#  'general[746216]': 519,
#  'history[3073871]': 385,
#  'jewish[916612]': 472,
#  'palladio, andrea[1034]': 14,
#  'artists, architects & photographers[2329]': 619,
#  'pop[2340]': 131,
#  'african-american & black[2366]': 1026,
#  'general[2369]': 1064,
#  'popular[4531]': 437,
#  'rock[4536]': 841,
#  'general[464252]': 448,
#  'object-oriented design[4013]': 839,
#  'metric system[13847]': 13,
#  'object-oriented design[727870]': 839,
#  'unabridged[2301]': 687,
#  'comic[4465]': 712,
#  'wodehouse, p.g.[70714]': 79,
#  'wodehouse, p. g.[586072]': 9,
#  'healing[4702]': 681,
#  'general[4708]': 284,
#  'techniques[4711]': 28,
#  'mental & spiritual healing[12671]': 433,
#  'critical & intensive care[14198]': 104,
#  'test preparation & review[14241]': 166,
#  'perinatology & neonatology[14394]': 83,
#  'critical & intensive care[227645]': 93,
#  'reviews & study guides[227665]': 152,
#  'perinatology & neonatology[227698]': 83,
#  'programming[3427]': 180,
#  'general[3927]': 319,
#  'programming[696946]': 180,
#  'programming[768670]': 180,
#  'african-american studies[11300]': 1177,
#  'douglass, frederick[284458]': 15,
#  'latin american[571676]': 50,
#  'dc comics[193766]': 533,
#  'general[193916]': 383,
#  'general[284552]': 55,
#  'paperback[285799]': 16,
#  'movie tie-ins[4497]': 542,
#  'blatty, william p.[5778]': 1,
#  'general[9808]': 1534,
#  'education[2734]': 606,
#  'administration[69830]': 738,
#  'education[768090]': 606,
#  'self-help[12683]': 450,
#  'healthy living[465686]': 835,
#  'general[2100]': 399,
#  'south[2104]': 98,
#  'west[2105]': 263,
#  'general[17333]': 47,
#  'general[640682]': 47,
#  'general[733710]': 399,
#  'south[733718]': 98,
#  'west[733720]': 263,
#  'general[12382]': 357,
#  'sociology[12807]': 468,
#  'catholic[12455]': 794,
#  'study[12211]': 635,
#  'topical[12240]': 626,
#  'old testament[572084]': 1035,
#  'general[720866]': 1535,
#  'international law[10898]': 358,
#  'systems & planning[2694]': 565,
#  'systems & planning[768014]': 565,
#  'compulsive behavior[11146]': 676,
#  'psychotherapy, ta & nlp[11203]': 1037,
#  "men's adventure[10179]": 311,
#  'war[10195]': 730,
#  'jones, james[70366]': 3,
#  'parent participation[10671]': 215,
#  'elementary school[69823]': 1802,
#  'general[69847]': 317,
#  'assembly language programming[3954]': 30,
#  'religious[2398]': 1343,
#  'mother theresa[173125]': 15,
#  'teresa, mother[297916]': 20,
#  'leaders[586086]': 61,
#  'women[586090]': 47,
#  'old testament[12161]': 392,
#  'old testament[12170]': 312,
#  'repair[10534]': 967,
#  'curricula[266136]': 498,
#  'general[465200]': 1056,
#  'hitler, adolf[917002]': 35,
#  'saints[12304]': 360,
#  'general[2976]': 2237,
#  'lewis, c.s.[170747]': 68,
#  'fantasy[3825111]': 47,
#  'german[11829]': 231,
#  'german[69736]': 37,
#  'poetry[12048]': 193,
#  'general[12329]': 601,
#  'church administration[12361]': 620,
#  'family & general practice[14313]': 188,
#  'family practice[227689]': 186,
#  'voice[1771]': 377,
#  'techniques[4547]': 487,
#  'pop culture[518484]': 355,
#  'pop culture[642278]': 274,
#  'homeopathy[171105]': 101,
#  'chinese medicine[282878]': 151,
#  'general[11897]': 330,
#  'general[745506]': 703,
#  'general[767964]': 703,
#  'general[1811]': 711,
#  'general[11260]': 683,
#  'catholic[12352]': 406,
#  'general[10557]': 339,
#  'terrorism[747400]': 699,
#  'september 11[1099208]': 205,
#  'european[2988]': 254,
#  'ethics & morality[11037]': 1010,
#  'egypt[4878]': 286,
#  'egypt[4997]': 421,
#  'greek & roman[11047]': 427,
#  'general[465274]': 409,
#  'metaphysics[11055]': 656,
#  'dickens, charles[10047]': 160,
#  'general[284622]': 151,
#  'hardcover[285661]': 40,
#  'action & adventure[720360]': 1212,
#  'cardiology[14323]': 366,
#  'cardiology[227630]': 358,
#  'missions & missionary work[12384]': 453,
#  'greek[10402]': 245,
#  'money & monetary policy[2598]': 164,
#  'banks & banking[2633]': 254,
#  ...}

# %% [markdown]
# Again, there are a lot of repetitive category entries. We'll regroup those together:

# %%
category_reduction = {}

for cat_key in categories_entr_count.keys():
    new_cat = cat_key.split('[')[0]
    if new_cat in category_reduction:
        category_reduction[new_cat] += categories_entr_count[cat_key]
    else:
        category_reduction[new_cat] = categories_entr_count[cat_key]

# %%
len(category_reduction)
# Out:
# 7912

# %%
sorted_categ_red_by_val = sorted(category_reduction.items(), key = operator.itemgetter(1), reverse=True)

# %%
sorted_categ_red_by_val
# Out:
# [('general', 555368),
#  ('fiction', 20574),
#  ('contemporary', 11948),
#  ('reference', 11657),
#  ('management', 9533),
#  ('history', 7615),
#  ('classics', 6470),
#  ('entrepreneurship', 6466),
#  ('united states', 6153),
#  ('literary', 5741),
#  ('nonfiction', 5647),
#  ('historical', 5506),
#  ('photo essays', 5496),
#  ('picture books', 5333),
#  ('action & adventure', 5273),
#  ('inspirational', 4905),
#  ('software development', 4872),
#  ('leadership', 4382),
#  ('humorous', 4038),
#  ('paperback', 3778),
#  ('women', 3534),
#  ('jp-unknown1', 3447),
#  ('devotionals', 3421),
#  ('guides', 3305),
#  ('science fiction, fantasy, & magic', 3286),
#  ('anthologies', 3180),
#  ('history & criticism', 3113),
#  ('finance & investing', 2997),
#  ('state & local', 2977),
#  ('new testament', 2950),
#  ('board books', 2916),
#  ('popular culture', 2908),
#  ('jp-unknown2', 2833),
#  ('20th century', 2777),
#  ('human resources & personnel management', 2650),
#  ('suspense', 2634),
#  ('software design', 2418),
#  ('english (all)', 2387),
#  ('essays & travelogues', 2386),
#  ('research', 2348),
#  ('personal transformation', 2294),
#  ('cultural', 2276),
#  ('advertising', 2262),
#  ('environmental science', 2261),
#  ('pedagogy', 2192),
#  ('relations', 2192),
#  ('motivational', 2188),
#  ('religious', 2178),
#  ('statistics', 2131),
#  ('political', 2104),
#  ('economic conditions', 2088),
#  ('fantasy', 2078),
#  ('windows - general', 2078),
#  ('modern', 2048),
#  ('parenting books', 2029),
#  ('spanish', 2005),
#  ('pacific', 1974),
#  ('women sleuths', 1935),
#  ('authors', 1922),
#  ('old testament', 1869),
#  ('economic policy & development', 1856),
#  ('science fiction', 1846),
#  ('video games', 1820),
#  ('ecology', 1810),
#  ('elementary school', 1802),
#  ('cognitive psychology', 1793),
#  ('history & theory', 1783),
#  ('study', 1777),
#  ('series', 1684),
#  ('object-oriented design', 1678),
#  ('international', 1676),
#  ('popular economics', 1669),
#  ('mysteries, espionage, & detectives', 1657),
#  ('interpersonal relations', 1631),
#  ('maps', 1568),
#  ('hardcover', 1566),
#  ('biochemistry', 1545),
#  ('jp-unknown3', 1542),
#  ('stories', 1528),
#  ('genetics', 1456),
#  ('policy & current events', 1448),
#  ('linguistics', 1434),
#  ('theory', 1433),
#  ('labor & industrial relations', 1428),
#  ('web site design', 1410),
#  ('web graphics', 1402),
#  ('education', 1382),
#  ('mechanics', 1381),
#  ('collections, catalogues & exhibitions', 1369),
#  ('military science', 1332),
#  ('marriage', 1309),
#  ('anatomy', 1304),
#  ('psychology', 1303),
#  ('decorating', 1300),
#  ('portraits', 1294),
#  ('introduction', 1289),
#  ('french', 1288),
#  ('catholic', 1285),
#  ('medieval', 1275),
#  ('love & romance', 1257),
#  ('u.s.', 1253),
#  ('european', 1251),
#  ('development & growth', 1250),
#  ('history of technology', 1235),
#  ('europe', 1228),
#  ('networking', 1227),
#  ('criticism', 1219),
#  ('test preparation & review', 1217),
#  ('probability & statistics', 1216),
#  ('training', 1191),
#  ('rock', 1189),
#  ('astronomy', 1188),
#  ('other', 1186),
#  ('african-american studies', 1184),
#  ('spy stories & tales of intrigue', 1173),
#  ('biotechnology', 1167),
#  ('business', 1152),
#  ('organizational behavior', 1150),
#  ('christian', 1138),
#  ('entertainers', 1134),
#  ('systems & planning', 1130),
#  ('adventure', 1128),
#  ('health care delivery', 1115),
#  ('workplace', 1110),
#  ('pop culture', 1094),
#  ('networks', 1094),
#  ('company histories', 1092),
#  ('atlases', 1079),
#  ('techniques', 1079),
#  ('comparative religion', 1072),
#  ('lonely planet', 1070),
#  ('popular', 1066),
#  ('counting', 1066),
#  ('geography', 1060),
#  ("manager's guides to computing", 1046),
#  ('british & irish', 1046),
#  ('guidebooks', 1042),
#  ('psychotherapy, ta & nlp', 1037),
#  ('epic', 1030),
#  ('african-american & black', 1026),
#  ('ethics & morality', 1010),
#  ('guitar', 1007),
#  ('general & reference', 1002),
#  ('natural resources', 1002),
#  ('gay', 997),
#  ('memoirs', 995),
#  ('police procedurals', 987),
#  ('ethics', 987),
#  ('directories', 979),
#  ('professional', 978),
#  ('cosmology', 978),
#  ('mid atlantic', 977),
#  ('19th century', 972),
#  ('geology', 969),
#  ('repair', 967),
#  ('advanced mechanics', 965),
#  ('corporate finance', 965),
#  ('folklore & mythology', 956),
#  ('landscape', 954),
#  ('essays', 948),
#  ('mystery', 940),
#  ('greek & roman', 934),
#  ('alphabet', 931),
#  ('spine-chilling horror', 929),
#  ('russia', 925),
#  ('cognitive science', 922),
#  ('programming', 920),
#  ('botany', 918),
#  ('nature & wildlife', 913),
#  ('nursing', 911),
#  ('unabridged', 907),
#  ('criminology', 904),
#  ('healthy', 903),
#  ('popular fiction', 895),
#  ('dining', 894),
#  ('conservation', 889),
#  ('calculus', 878),
#  ('comics & graphic novels', 877),
#  ('quality control', 871),
#  ('prayer', 867),
#  ('mis', 862),
#  ('reading', 854),
#  ('web marketing', 850),
#  ('south atlantic', 840),
#  ('ethnic studies', 840),
#  ('self help', 835),
#  ('healthy living', 835),
#  ('tourist destinations & museums', 830),
#  ('lesson planning', 828),
#  ('direction & production', 828),
#  ('administration', 822),
#  ('internet publishing', 815),
#  ('ritual', 814),
#  ('college', 813),
#  ('holocaust', 812),
#  ('dictionaries & terminology', 810),
#  ('ages 9-12', 803),
#  ('naval', 802),
#  ('italian', 802),
#  ('customer service', 802),
#  ('church institutions & organizations', 801),
#  ('quilts & quilting', 801),
#  ('drawing', 798),
#  ('archaeology', 797),
#  ('public health', 796),
#  ('law enforcement', 795),
#  ('microbiology', 790),
#  ('physical therapy', 790),
#  ('mental illness', 787),
#  ('new england', 779),
#  ('japanese', 779),
#  ('coloring books', 777),
#  ('native american', 775),
#  ('british', 772),
#  ("frommer's", 770),
#  ('high school', 769),
#  ('multicultural', 765),
#  ('religion & spirituality', 762),
#  ('decision-making & problem solving', 760),
#  ('mountain', 755),
#  ('cardiology', 754),
#  ('west', 753),
#  ('parks & campgrounds', 752),
#  ('military & spies', 751),
#  ('business law', 750),
#  ('security', 748),
#  ('software project management', 747),
#  ('aviation', 745),
#  ('japan', 739),
#  ('healing', 736),
#  ('obstetrics & gynecology', 736),
#  ('pharmacy', 733),
#  ('war', 730),
#  ('pictorial', 728),
#  ('success', 728),
#  ('study & teaching', 727),
#  ('history of science', 724),
#  ('feminist theory', 719),
#  ('civil procedure', 719),
#  ('travel', 716),
#  ('comic', 712),
#  ('buildings & construction', 711),
#  ('non-us legal systems', 708),
#  ('egypt', 707),
#  ('magic', 706),
#  ('adventure & thrillers', 705),
#  ('lesbian', 702),
#  ('self-esteem', 701),
#  ('human', 701),
#  ('terrorism', 699),
#  ('breeds', 698),
#  ('strategy & competition', 698),
#  ('organic', 696),
#  ('referencia', 694),
#  ('instruction & study', 691),
#  ('russian', 691),
#  ('new experiences', 690),
#  ('meditations', 690),
#  ('chinese', 687),
#  ('statistical computing', 686),
#  ('grammar', 684),
#  ("women's issues", 681),
#  ('meditation', 681),
#  ('birds', 678),
#  ('mammals', 678),
#  ('compulsive behavior', 676),
#  ('neuroscience', 674),
#  ('international law', 673),
#  ('ministry', 672),
#  ('native american studies', 672),
#  ('metaphysics', 668),
#  ('hospitality, travel & tourism', 664),
#  ('media studies', 657),
#  ('organizational change', 656),
#  ('inspiration & philosophy', 655),
#  ('inspiration', 654),
#  ('german', 652),
#  ('history & surveys', 652),
#  ('nonprofit organizations & charities', 650),
#  ('family saga', 648),
#  ('style', 648),
#  ('midwest', 647),
#  ('fashion', 645),
#  ('writing skills', 641),
#  ('continental european', 640),
#  ('e-mail', 636),
#  ('jewish', 635),
#  ('4 a 8 años', 631),
#  ('ages 4-8', 628),
#  ('south', 626),
#  ('topical', 626),
#  ('stocks', 624),
#  ('philosophy', 623),
#  ('1800s', 621),
#  ('church administration', 620),
#  ('artists, architects & photographers', 619),
#  ('physiology', 618),
#  ('client-server systems', 614),
#  ('culture', 612),
#  ('neuropsychology', 610),
#  ('physical & theoretical', 608),
#  ('short story collections', 606),
#  ('activities & toys', 604),
#  ('horror', 599),
#  ('murder & mayhem', 599),
#  ('equipment', 598),
#  ('communication', 597),
#  ('customs & traditions', 595),
#  ('british detectives', 593),
#  ('video & electronic games', 588),
#  ('asian', 587),
#  ('piano', 585),
#  ('herbal remedies', 584),
#  ('shakespeare', 584),
#  ('literature & fiction', 583),
#  ('visual basic', 579),
#  ('christology', 579),
#  ('yoga', 578),
#  ('physical medicine & rehabilitation', 574),
#  ('quantum theory', 573),
#  ('futures', 572),
#  ('astrophysics & space science', 572),
#  ('pottery & ceramics', 570),
#  ('secrets of success', 568),
#  ('management science', 568),
#  ('banks & banking', 567),
#  ('privacy', 566),
#  ('general & post-columbus', 565),
#  ('electrical & electronics', 563),
#  ('consciousness & thought', 562),
#  ('weight loss', 560),
#  ('labor policy', 558),
#  ('legal', 548),
#  ('psychoanalysis', 546),
#  ('design & construction', 546),
#  ('self-help', 545),
#  ('sociology', 545),
#  ('renaissance', 544),
#  ('office skills', 544),
#  ('investing', 543),
#  ('movie tie-ins', 542),
#  ('african american', 540),
#  ('civil rights & liberties', 539),
#  ('spirits', 536),
#  ('computers', 534),
#  ('practical politics', 533),
#  ('dc comics', 533),
#  ('weight maintenance', 531),
#  ('public policy', 530),
#  ('financial planning', 528),
#  ('vocational guidance', 528),
#  ('rome', 528),
#  ('witchcraft', 527),
#  ('discrimination & racism', 527),
#  ('bedtime & dreaming', 527),
#  ('guides & reviews', 527),
#  ('study guides', 526),
#  ('happiness', 523),
#  ('medical ethics', 523),
#  ('gifts', 521),
#  ('polyglot', 519),
#  ('asia', 516),
#  ('network security', 515),
#  ('adult fiction', 515),
#  ('urban', 514),
#  ('international security', 512),
#  ('quotations', 511),
#  ('regency', 507),
#  ('sports', 506),
#  ('exports & imports', 506),
#  ('general surgery', 505),
#  ('mathematical analysis', 504),
#  ('mate seeking', 503),
#  ('jazz', 503),
#  ('greek', 502),
#  ('colors', 502),
#  ('meetings & presentations', 502),
#  ('books', 501),
#  ('database management systems', 500),
#  ('shakespeare, william', 500),
#  ('dictionaries', 499),
#  ('curricula', 498),
#  ('historical fiction', 497),
#  ('money management', 497),
#  ('special needs children', 495),
#  ('true crime', 495),
#  ('social psychology & interactions', 494),
#  ('emotions', 494),
#  ('nature writing', 493),
#  ('social services & welfare', 493),
#  ('writing', 492),
#  ('wicca', 490),
#  ('molecular biology', 490),
#  ('mountain climbing', 489),
#  ('america', 488),
#  ('child care', 488),
#  ('for dummies: general', 488),
#  ('medical', 486),
#  ('personality', 484),
#  ('grief & bereavement', 484),
#  ('hard-boiled', 480),
#  ('circuits', 480),
#  ('semiotics', 480),
#  ('pregnancy & childbirth books', 479),
#  ('options', 478),
#  ('audiology & speech pathology', 475),
#  ('assessment', 474),
#  ('garden design', 474),
#  ('superheroes', 472),
#  ('rhetoric', 472),
#  ('wildlife', 472),
#  ('democracy', 470),
#  ('pathologies', 469),
#  ('romance', 469),
#  ('jewish life', 468),
#  ('low fat', 466),
#  ('preschool & kindergarten', 466),
#  ('projects', 463),
#  ('african-american', 461),
#  ('macroeconomics', 461),
#  ('puzzles', 459),
#  ('social work', 459),
#  ('industrial', 459),
#  ('motor sports', 458),
#  ('ufos', 456),
#  ('anatomy & physiology', 454),
#  ('missions & missionary work', 453),
#  ('biographies & memoirs', 453),
#  ('mexico', 453),
#  ('acoustics & sound', 452),
#  ('general geometry', 450),
#  ('photojournalism', 450),
#  ('naturopathy', 450),
#  ('motherhood', 449),
#  ('youth ministry', 449),
#  ('family travel', 448),
#  ('protestant', 448),
#  ('testing', 447),
#  ('crafts & hobbies', 447),
#  ('html - general', 447),
#  ('policy', 445),
#  ('personal narratives', 444),
#  ('scientists', 444),
#  ('faith', 440),
#  ('economic history', 439),
#  ('business history', 439),
#  ('stress management', 439),
#  ('boating', 438),
#  ('taoism', 438),
#  ('photodeluxe & photoshop', 438),
#  ('diagnostic imaging', 437),
#  ('spain', 436),
#  ('religión y espiritualidad', 435),
#  ('diagnosis', 434),
#  ('instructional', 434),
#  ('mental & spiritual healing', 433),
#  ('social theory', 433),
#  ('sustainable development', 432),
#  ('financial', 431),
#  ('personal growth', 430),
#  ('apologetics', 429),
#  ('child development', 429),
#  ('actors & actresses', 429),
#  ('educational psychology', 428),
#  ('internet marketing', 425),
#  ('israel', 424),
#  ('behavioral psychology', 424),
#  ('development', 423),
#  ('analytic', 423),
#  ('production & operations', 422),
#  ('mathematical physics', 422),
#  ('cycling', 421),
#  ('poetry', 421),
#  ('emigration & immigration', 420),
#  ('investments', 420),
#  ('paris', 420),
#  ('cooking', 416),
#  ('pastoral counseling', 414),
#  ('hotels & inns', 414),
#  ('women writers', 414),
#  ('public affairs & administration', 413),
#  ('marriage & family', 412),
#  ('sales', 412),
#  ('aeronautics & astronautics', 412),
#  ('electricity principles', 411),
#  ('residential', 409),
#  ('captains of industry', 409),
#  ('web-based education', 408),
#  ('clinical psychology', 407),
#  ('negotiating', 404),
#  ('drug guides', 404),
#  ('stine, r. l.', 403),
#  ('communicable diseases', 402),
#  ('journalism', 402),
#  ('screenwriting', 402),
#  ('microeconomics', 401),
#  ('book notes', 399),
#  ('philosophy & social aspects', 399),
#  ('for dummies: applications', 398),
#  ('music', 398),
#  ('nutrition', 397),
#  ('high tech', 397),
#  ('dysfunctional relationships', 396),
#  ('science', 396),
#  ('acting & auditioning', 395),
#  ('india', 394),
#  ('ophthalmology', 392),
#  ('unexplained mysteries', 392),
#  ('london', 392),
#  ('budget travel', 392),
#  ('manufacturing', 391),
#  ('vietnam war', 391),
#  ('collections & readers', 389),
#  ('teenagers', 389),
#  ('1900s', 389),
#  ('child-development books', 389),
#  ('new business enterprises', 388),
#  ('industry', 387),
#  ('divorce', 387),
#  ('commercial', 386),
#  ('prayerbooks', 385),
#  ('almanacs', 385),
#  ('cell biology', 385),
#  ('care & health', 384),
#  ('internet newcomer', 382),
#  ('flowers', 381),
#  ('trees', 381),
#  ('chess', 379),
#  ('home based', 378),
#  ('history of sports', 378),
#  ('engineering', 378),
#  ('voice', 377),
#  ('technical', 377),
#  ('industrial technology', 376),
#  ('personal finance', 376),
#  ('reptiles & amphibians', 376),
#  ('racing', 375),
#  ('sewing', 374),
#  ('mysticism', 374),
#  ('special needs', 374),
#  ('dictionaries; polyglot', 374),
#  ('physical examination', 373),
#  ('eastern philosophy', 373),
#  ('latin american', 372),
#  ('saints', 370),
#  ('consumerism', 370),
#  ('clip art', 369),
#  ('database design', 369),
#  ('dark horse', 369),
#  ('decoration & ornament', 369),
#  ('laboratory medicine', 367),
#  ('total quality management', 366),
#  ('urban & land use planning', 366),
#  ('running & jogging', 366),
#  ('preaching', 364),
#  ('satire, general', 364),
#  ('optics', 364),
#  ('trucks & vans', 362),
#  ('epidemiology', 361),
#  ('dreams', 361),
#  ('words', 360),
#  ('retirement planning', 358),
#  ('presidents & heads of state', 358),
#  ('oncology', 358),
#  ('literacy', 358),
#  ('star wars', 357),
#  ('relaxation & meditation', 357),
#  ('low-fat diet', 356),
#  ('art', 356),
#  ('california', 356),
#  ('emergency', 355),
#  ('new york city', 354),
#  ('large print', 353),
#  ('materials', 353),
#  ('mystery & thrillers', 353),
#  ('christianity', 352),
#  ('furniture', 351),
#  ('careers', 351),
#  ('public relations', 350),
#  ('science fiction & fantasy', 348),
#  ('pentecostal', 347),
#  ('architectural', 346),
#  ('jewelry', 345),
#  ('journalists', 344),
#  ('discipleship', 343),
#  ('immunology', 343),
#  ('windows nt', 343),
#  ('women writers & feminist theory', 343),
#  ('composition', 342),
#  ('teams', 342),
#  ('word processing', 342),
#  ('occupational therapy', 341),
#  ('glass & glassware', 340),
#  ('econometrics', 340),
#  ('macintosh', 340),
#  ('logic', 340),
#  ('resumes', 340),
#  ('epistemology', 339),
#  ('seasonal', 339),
#  ('hunting', 339),
#  ('consulting', 338),
#  ('macs', 337),
#  ('africa', 337),
#  ('legal history', 336),
#  ('machinery', 336),
#  ('lesbian studies', 335),
#  ('new international', 335),
#  ('tarot', 333),
#  ('painting', 333),
#  ('digital photography', 333),
#  ('internet & education', 330),
#  ('depression', 329),
#  ('online searching', 328),
#  ('women & business', 328),
#  ('soteriology', 327),
#  ('differential equations', 323),
#  ('zen', 323),
#  ('human rights', 323),
#  ('feminist', 322),
#  ('pathophysiology', 318),
#  ('sense & sensation', 318),
#  ('parodies', 318),
#  ('library science & guidance', 317),
#  ('west south central', 316),
#  ('sermons', 315),
#  ('greece', 313),
#  ('anesthesiology', 313),
#  ('calligraphy', 313),
#  ('robotics', 311),
#  ("men's adventure", 311),
#  ('rheumatology', 310),
#  ('curiosities & wonders', 309),
#  ('domestic life', 308),
#  ('eschatology', 306),
#  ('couples & family therapy', 306),
#  ('tibetan', 305),
#  ('safety & health', 303),
#  ('discrete mathematics', 302),
#  ('non-religious', 302),
#  ('african', 302),
#  ('thermodynamics', 301),
#  ('adolescent psychology', 300),
#  ('aims & objectives', 300),
#  ('number theory', 300),
#  ('irish', 300),
#  ('mcse', 299),
#  ('arabic', 298),
#  ('military & wars', 298),
#  ('fantasy, futuristic & ghost', 298),
#  ('time', 298),
#  ('no ficción', 297),
#  ('communism & socialism', 297),
#  ('vegetables', 296),
#  ('sports medicine', 296),
#  ('radiologic & ultrasound technology', 296),
#  ('business writing', 296),
#  ('conspiracy theories', 295),
#  ('language experience approach', 295),
#  ('textile arts', 295),
#  ('toxicology', 295),
#  ('pharmacology', 295),
#  ('urban planning & development', 294),
#  ('safety & first aid', 294),
#  ('people of color', 293),
#  ('buying & selling homes', 292),
#  ('old west', 292),
#  ('early civilization', 291),
#  ('systems analysis & design', 290),
#  ('specific styles', 290),
#  ('retailing', 290),
#  ('electromagnetism', 289),
#  ('cartooning', 289),
#  ('canada', 289),
#  ('bridges & routers', 289),
#  ('infants', 288),
#  ('historiography', 287),
#  ('endocrinology & metabolism', 287),
#  ('humor', 287),
#  ('solid state physics', 287),
#  ('assessment & diagnosis', 286),
#  ('controversial knowledge', 286),
#  ('charismatic', 286),
#  ('do-it-yourself', 286),
#  ('vampires', 286),
#  ('human geography', 284),
#  ('tokyopop', 284),
#  ('family health', 284),
#  ('family activities', 283),
#  ('study bibles', 283),
#  ('spiritualism', 282),
#  ('programming languages', 282),
#  ('eating disorders', 282),
#  ('classic cars', 282),
#  ('parapsychology', 282),
#  ('orthopedics', 281),
#  ('fundamentals & skills', 280),
#  ('injuries & rehabilitation', 278),
#  ('medical assistants', 276),
#  ('multilevel', 276),
#  ('cats, dogs & animals', 275),
#  ('vocabulary', 274),
#  ('inspirational & religious', 273),
#  ('authorship', 272),
#  ('pain medicine', 272),
#  ('world war i', 272),
#  ('logic & language', 272),
#  ('knitting', 271),
#  ('academic & commercial', 271),
#  ('capital generation', 270),
#  ('substance abuse', 270),
#  ('food science', 270),
#  ('military', 269),
#  ('hispanic & latino', 268),
#  ('sports & recreation', 268),
#  ('digital design', 268),
#  ('nuclear physics', 268),
#  ('marvel', 267),
#  ('practice management & reimbursement', 267),
#  ('software', 267),
#  ('elections', 266),
#  ('hackers', 266),
#  ('entomology', 266),
#  ('organizational learning', 266),
#  ('all french books', 266),
#  ('metallurgy', 266),
#  ('xml', 264),
#  ('dr. seuss', 263),
#  ('prophecy', 262),
#  ('time management', 261),
#  ('abuse', 261),
#  ('meteorology', 260),
#  ('weather', 260),
#  ('mysteries', 259),
#  ('chaos & systems', 259),
#  ('emergency medicine', 258),
#  ('robotics & automation', 258),
#  ('insight guide', 258),
#  ('osborne-mcgraw-hill', 257),
#  ('devotional', 257),
#  ('company profiles', 256),
#  ('small animal medicine', 256),
#  ('literary classics', 256),
#  ('dermatology', 256),
#  ('infant-development books', 255),
#  ('graphics, animation & illustration', 254),
#  ('united states civil war', 253),
#  ('gerontology', 253),
#  ('methodology & statistics', 252),
#  ('psychological & suspense', 252),
#  ('jurisprudence', 251),
#  ('humanism', 251),
#  ('jokes & riddles', 249),
#  ('spiritual', 246),
#  ("children's books", 246),
#  ('medical history & records', 245),
#  ('science & religion', 245),
#  ('decorative', 244),
#  ('wine & winemaking', 244),
#  ('creativity', 244),
#  ('criminal procedure', 243),
#  ('human vision & language systems', 242),
#  ('computers & technology', 242),
#  ('public speaking', 242),
#  ("all children's boxed sets", 242),
#  ('monsters', 241),
#  ('sea adventures', 241),
#  ('for beginners', 240),
#  ('portuguese', 240),
#  ('east south central', 240),
#  ("let's go", 240),
#  ('planning & forecasting', 240),
#  ('mechanical', 239),
#  ('desserts', 238),
#  ('earth sciences', 238),
#  ('fish & sharks', 237),
#  ('orphans & foster homes', 237),
#  ('social policy', 237),
#  ('marine biology', 237),
#  ('personal hygiene', 236),
#  ('interviewing', 236),
#  ('student life', 236),
#  ('culinary arts & techniques', 236),
#  ('biology', 235),
#  ('consumer guides', 235),
#  ('native north & south americans', 235),
#  ('bibliographies & indexes', 235),
#  ('feng shui', 235),
#  ('science & technology', 234),
#  ('high-tech', 234),
#  ('databases', 234),
#  ('methodology', 234),
#  ('gastroenterology', 234),
#  ('food sciences', 233),
#  ('developmental psychology', 232),
#  ('trivia', 232),
#  ('men', 232),
#  ('production, operation & management', 232),
#  ('lan', 232),
#  ('customs, traditions, anthropology', 232),
#  ('critical care', 231),
#  ('patent, trademark & copyright', 229),
#  ('shopping & commerce', 229),
#  ('models', 229),
#  ('word', 228),
#  ('structured design', 228),
#  ('consolidation & merger', 228),
#  ('nervous system', 227),
#  ('strategy', 227),
#  ('literature', 226),
#  ('desktop publishing', 226),
#  ('negocios e inversiones', 225),
#  ('web multimedia', 225),
#  ('diet therapy', 225),
#  ('customize', 225),
#  ('business & investing', 225),
#  ('animals', 224),
#  ('emergency medical services', 224),
#  ('careers & business life', 224),
#  ('twain, mark', 223),
#  ("alzheimer's disease", 223),
#  ('sat & psat', 223),
#  ('watercolor painting', 222),
#  ('criticism & essays', 222),
#  ('personal taxes', 222),
#  ('religion', 221),
#  ('aesthetics', 221),
#  ('cellular communications', 221),
#  ('staff favorites', 221),
#  ('fatherhood', 221),
#  ('walking', 221),
#  ('prophecies', 220),
#  ('insects & spiders', 220),
#  ('aging', 219),
#  ('slang & idioms', 218),
#  ('acupuncture & acupressure', 218),
#  ('history of religion', 218),
#  ('free enterprise', 218),
#  ('eastern', 218),
#  ('school-age children', 216),
#  ('kabbalah', 216),
#  ('linear', 216),
#  ('state & local government', 216),
#  ('chiropractic', 216),
#  ('parent participation', 215),
#  ('relativity', 215),
#  ('adobe photoshop', 215),
#  ('miscellaneous', 215),
#  ('research & theory', 215),
#  ('typography', 214),
#  ('health policy', 214),
#  ('stagecraft', 213),
#  ('repair & performance', 213),
#  ('legal profession', 213),
#  ('political parties', 212),
#  ('piloting & flight instruction', 212),
#  ('tips', 212),
#  ('email', 212),
#  ('medical & surgical', 212),
#  ('applied psychology', 211),
#  ('orchestral', 211),
#  ('zen philosophy', 211),
#  ('word games', 211),
#  ('dark fantasy', 211),
#  ('strings', 210),
#  ('budgeting', 210),
#  ('san francisco', 210),
#  ('occultism', 209),
#  ('stereo & audio equipment', 209),
#  ('regional', 209),
#  ('medical atlases', 209),
#  ('otolaryngology', 208),
#  ('bodybuilding & weight training', 208),
#  ('thriller', 207),
#  ('angels', 206),
#  ('family & childhood', 206),
#  ('september 11', 205),
#  ('textile & costume', 205),
#  ('hematology', 205),
#  ('intelligence & espionage', 204),
#  ('arthurian', 204),
#  ('holistic', 203),
#  ('clinical chemistry', 202),
#  ('pulmonary', 202),
#  ('minority studies', 201),
#  ('pocket', 201),
#  ('lighting', 201),
#  ('forensic science', 201),
#  ('testing & measurement', 201),
#  ('expert systems', 201),
#  ('rocks & minerals', 200),
#  ('questions & answers', 199),
#  ('nutshell', 199),
#  ('waves & wave mechanics', 198),
#  ('new thought', 198),
#  ('forensic medicine', 198),
#  ('critical & intensive care', 197),
#  ('colonial', 197),
#  ('linear programming', 197),
#  ('performing arts', 196),
#  ('penology', 196),
#  ('insiders', 196),
#  ('technothrillers', 196),
#  ('legal guides', 196),
#  ('study skills', 196),
#  ('auditing', 196),
#  ('theology', 195),
#  ('college guides', 195),
#  ('nurse & patient', 195),
#  ('9 a 12 años', 195),
#  ('hypnosis', 194),
#  ('cuba', 194),
#  ('biography', 194),
#  ('medical technology', 194),
#  ('etiquette', 193),
#  ('semiconductors', 192),
#  ('wireless communications', 192),
#  ('moon handbooks', 192),
#  ('diabetes', 192),
#  ('optometry', 192),
#  ('acupuncture', 192),
#  ('batman', 191),
#  ('new zealand', 191),
#  ('1945 - present', 191),
#  ('physical', 191),
#  ('credit repair', 190),
#  ('holidays', 189),
#  ('musicals', 189),
#  ('musculoskeletal diseases', 189),
#  ('family & general practice', 188),
#  ('uml', 188),
#  ('adoption', 188),
#  ('ecotourism', 188),
#  ('bread', 187),
#  ('occupational & organizational', 187),
#  ('printmaking', 187),
#  ('lift the flap', 187),
#  ('letters & correspondence', 187),
#  ('marine life', 187),
#  ('biostatistics', 187),
#  ('carroll, lewis', 187),
#  ('marketing', 187),
#  ('war & peace', 186),
#  ("autism & asperger's syndrome", 186),
#  ('family practice', 186),
#  ('dickens, charles', 186),
#  ('royalty', 186),
#  ('reading skills', 186),
#  ('sybex', 186),
#  ('viz', 186),
#  ('television & video', 186),
#  ("discographies & buyer's guides", 186),
#  ('radical thought', 185),
#  ('carpentry', 185),
#  ('divorce & separation', 185),
#  ('postcards', 185),
#  ('estates & trusts', 185),
#  ('distributed databases', 185),
#  ('switzerland', 184),
#  ('aids', 184),
#  ('experimental', 184),
#  ('18th century', 184),
#  ('radio & wireless', 183),
#  ('outdoor & recreational areas', 183),
#  ('firearms & weapons', 183),
#  ('ecclesiology', 183),
#  ('active server pages', 182),
#  ('painting & wallpapering', 182),
#  ('camping', 182),
#  ('green guides', 182),
#  ('legal system', 182),
#  ('algebraic geometry', 182),
#  ('kipling, rudyard', 182),
#  ('textiles & costume', 181),
#  ('buddha', 181),
#  ('metaphysical phenomena', 181),
#  ("children's studies", 180),
#  ('opposites', 180),
#  ('intermediate', 180),
#  ('chicago', 180),
#  ('tax law', 180),
#  ('arabesque', 180),
#  ('language studies', 180),
#  ('needlework', 180),
#  ('learning disorders', 180),
#  ('physiological aspects', 179),
#  ('philosophers', 179),
#  ('middle eastern', 179),
#  ('tibet', 178),
#  ('courts', 178),
#  ('maine', 178),
#  ('reference & collections', 178),
#  ('computer mathematics', 178),
#  ('government', 178),
#  ('phrasebooks - general', 177),
#  ('parenting & families', 177),
#  ('functional analysis', 177),
#  ('literature guides', 176),
#  ('planning', 176),
#  ('friendship', 176),
#  ('wilde, oscar', 176),
#  ...]

# %% [markdown]
# Let's calculate the sum of all category frequencies:

# %%
sum_sorted_red = sum([x[1] for x in sorted_categ_red_by_val])

# %%
sum_sorted_red
# Out:
# 1440329

# %% [markdown]
# Next, we find the index of the array for the category items that are encountered less than 10% in the product:

# %%
(np.cumsum([x[1]/sum_sorted_red for x in sorted_categ_red_by_val]) < 0.9).argmin()
# Out:
# 1313

# %%
sorted_categ_red_by_val[1313]
# Out:
# ('horoscopes', 119)

# %% [markdown]
# We can reduce the number of categories by 10% by removing all the category entries with a frequency less than 118.
#
# Now, we can answer both the questions asked above:
#
#     a. there is a redundancy of categories, there are a lot of repetitive entities but differ only by IDs. It means there were entered several categories.
#     b. we can reduce further the number of categories by removing the least used (< 118)

# %% [markdown]
# ## Part B
#
#     1. How would build the product categorization from scratch, using similar/co-purchased information?
#
#     There are 2 aspects that cause category items duplication: entering several times the same entity (and different ID) and also creating categories that are not necessary (less frequently used). To prevent entering the same category twice we should check whether it exists and also make sure there is no duplication by using another foreign language. Or another alternative is to search for similar category in the database before creating a new category. In order to generate (create) a new category we should check whether 119 or more books share a distinct feature that does not exist as an entry in the database.
#
#     2. Product thinking
#     Now, put on your 'product thinking' hat.
#     a. Is it a good idea to show users the categorization hierarchy for items?
#
#    **As we saw above, we can identify redundancy issues related to category entries by exposing the full categorization hierarchy to users. Which is a weakness in the product and probably leads to a less than a great user experience. However, this level of transparency is necessary. On premises that the categorization is achieved automatically, this level of transparency gives a user an opportunity to provide feedback whenever a discrepancy is encountered. Showing the categorization hierarchy for items demonstrates that we have assessed the quality of the product and it complies with the basic requirements.**
#
#     b. Is it a good idea to show users similar/co-purchased items?
#
#    **Showing users other similar/co-purchased items is a way to influence them to buy more products. While it might seem aggressive, if done properly it can result in a big outcome. It is important to show users relevant similar items which they most probably will purchase. This strategy should play very well in combination with recommender systems.**
#
#     c. Is it a good idea to show users reviews and ratings for items?
#
#    **It has been established that most people decide to purchase items based on the peers' reviews. Unfortunately, bad reviews could draw the users away while good reviews might bias the decisions and make it more difficult for new items in the market. Combined with reviews, the ratings are a powerful way to judge about a quality of the product. As we saw above, voting a review and its helpfulness leads to a better judgement on rating trusworthiness.**
